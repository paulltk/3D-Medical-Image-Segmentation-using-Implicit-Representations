# %%
import torch
import torch.nn.functional as F

from torch import nn
from torch.utils.data import DataLoader, Dataset
from torchvision.transforms import Resize, Compose, ToTensor, Normalize

import argparse
import os
import math 
import skimage
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import time
import pickle

from datetime import datetime
from pathlib import Path

# from data_classes.py_files.custom_datasets import *
# from data_classes.py_files.data_classes import *
from py_files.new_dataset import *

from py_files.cnn_model import *
from py_files.pigan_model import *

from py_files.pi_gan_functions import *

# %matplotlib qt
# Out:
# Imported CNN and Mapping functions.
# Imported PI-Gan model.
# Loaded all helper functions.

# %%
def show_runs(requirements, print_vars, last=None):
    runs = sorted(os.listdir(path='saved_runs'))
    
    if last: 
        runs = runs[-last:]
        
    for run in runs:
        if run != "old":
            ARGS = load_args(run, print_changed=False)

            if all([requirements[key] == vars(ARGS)[key] for key in requirements.keys()]):

                print(f"\n{run}\n")

                if print_vars:
                    for key in print_vars:
                        if key in vars(ARGS).keys():
                            print(f"{key}: {vars(ARGS)[key]}")
                        else: 
                            print(f"{key} not in ARGS")
                else:
                    for key, item in vars(ARGS).items():
                        print(f"{key}: {item}")

                print()

                mask_losses = pcmra_losses = dice_losses = None

                if os.path.exists(f'saved_runs/{run}/mask_loss.npy'):
                    mask_losses = np.load(f'saved_runs/{run}/mask_loss.npy')

                if os.path.exists(f'saved_runs/{run}/pcmra_loss.npy'):
                    pcmra_losses = np.load(f'saved_runs/{run}/pcmra_loss.npy')

                if os.path.exists(f'saved_runs/{run}/dice_loss.npy'):
                    dice_losses = np.load(f'saved_runs/{run}/dice_loss.npy')

                fig, axes = plt.subplots(1, 3, figsize=(18,5))
                fig.patch.set_facecolor('white')

                if type(mask_losses) == np.ndarray:
                    axes[0].plot(mask_losses[1:, 0], mask_losses[1:, 1], label='Train loss')
                    axes[0].plot(mask_losses[1:, 0], mask_losses[1:, 3], label='Eval loss')
                    axes[0].set_title('Mask Loss')

                    i1, i2 = mask_losses[:, 1].argmin(), mask_losses[:, 3].argmin()
                    print(f"Lowest train mask loss at epoch {int(mask_losses[i1, 0])}:\t{round(mask_losses[i1, 1], 6)}")
                    print(f"Lowest eval  mask loss at epoch {int(mask_losses[i2, 0])}:\t{round(mask_losses[i2, 3], 6)}")
                    print()

                if type(pcmra_losses)  == np.ndarray:
                    axes[1].plot(pcmra_losses[1:, 0], pcmra_losses[1:, 1], label='Train loss')
                    axes[1].plot(pcmra_losses[1:, 0], pcmra_losses[1:, 3], label='Eval loss')
                    axes[1].set_title('PCMRA Loss')
                    i5, i6 = pcmra_losses[:, 1].argmin(), pcmra_losses[:, 3].argmin()
                    print(f"Lowest train pcmra loss at epoch {int(pcmra_losses[i5, 0])}:\t{round(pcmra_losses[i5, 1], 6)}")
                    print(f"Lowest eval  pcmra loss at epoch {int(pcmra_losses[i6, 0])}:\t{round(pcmra_losses[i6, 3], 6)}")
                    print()
                if type(dice_losses) == np.ndarray:
                    axes[2].plot(dice_losses[1:, 0], dice_losses[1:, 1], label='Train loss')
                    axes[2].plot(dice_losses[1:, 0], dice_losses[1:, 3], label='Eval loss')
                    axes[2].set_title('Dice Loss')

                    i3, i4 = dice_losses[:, 1].argmin(), dice_losses[:, 3].argmin()
                    print(f"Lowest train dice loss at epoch {int(dice_losses[i3, 0])}:\t{round(dice_losses[i3, 1], 6)}")
                    print(f"Lowest eval  dice loss at epoch {int(dice_losses[i4, 0])}:\t{round(dice_losses[i4, 3], 6)}")


                plt.show()

                print("\n\n\n")

# %%
## requirements = {"cnn_setup": 14}
requirements = {}

# print_vars = ["pretrained", "cnn_setup", "mapping_setup", "cnn_wd", "rotate", "translate", "flip", "stretch", "crop"]
print_vars = ["cnn_setup", "mapping_setup", "pretrained", "pretrained_lr_reset", "min_lr", "pcmra_first_omega_0", "first_omega_0", "translate_max_pixels", "mask_train_cnn", "siren_wd"]
# print_vars = None

show_runs(requirements, print_vars, last=None)
# Out:
# WARNING: ARGS class initialized.
#
# pi-gan 01-06-2021 12:09:41
#
# pretrained: None
# pretrained_lr_reset: None
# min_lr: 5e-06
# pcmra_first_omega_0: 100.0
# first_omega_0: 30.0
# translate_max_pixels: 20
# mask_train_cnn: True
# siren_wd: 0.0001
#
# Lowest train mask loss at epoch 0:	0.573854
# Lowest eval  mask loss at epoch 0:	0.576519
# WARNING: ARGS class initialized.
#
# pi-gan 22-05-2021 04:28:59 cnn setup 6 mapping setup 7
#
# pretrained: None
# pretrained_lr_reset: None
# min_lr not in ARGS
# pcmra_first_omega_0: 30.0
# first_omega_0: 30.0
# translate_max_pixels not in ARGS
# mask_train_cnn: False
# siren_wd: 0
#
# Lowest train mask loss at epoch 2300:	0.021304
# Lowest eval  mask loss at epoch 1300:	0.039385
#
# Lowest train pcmra loss at epoch 4800:	0.001177
# Lowest eval  pcmra loss at epoch 4500:	0.001511
#
# Lowest train dice loss at epoch 2300:	0.141556
# Lowest eval  dice loss at epoch 1300:	0.25903
# WARNING: ARGS class initialized.
#
# pi-gan 23-05-2021 20:33:49 cnn setup 14 mapping setup 7 continuing
#
# pretrained: pi-gan 23-05-2021 16:26:08 cnn setup 14 mapping setup 7
# pretrained_lr_reset: None
# min_lr not in ARGS
# pcmra_first_omega_0: 30.0
# first_omega_0: 30.0
# translate_max_pixels not in ARGS
# mask_train_cnn: False
# siren_wd: 0
#
# Lowest train mask loss at epoch 2300:	0.023588
# Lowest eval  mask loss at epoch 1750:	0.038738
#
# Lowest train pcmra loss at epoch 900:	0.001287
# Lowest eval  pcmra loss at epoch 500:	0.001538
#
# Lowest train dice loss at epoch 2300:	0.157579
# Lowest eval  dice loss at epoch 1750:	0.2507
# WARNING: ARGS class initialized.
#
# pi-gan 25-05-2021 19:43:38 cnn setup -2 mapping setup 7
#
# pretrained: None
# pretrained_lr_reset: None
# min_lr not in ARGS
# pcmra_first_omega_0: 30.0
# first_omega_0: 30.0
# translate_max_pixels not in ARGS
# mask_train_cnn: False
# siren_wd: 0
#
# Lowest train mask loss at epoch 2450:	0.023538
# Lowest eval  mask loss at epoch 1700:	0.03855
#
# Lowest train pcmra loss at epoch 4750:	0.00126
# Lowest eval  pcmra loss at epoch 4100:	0.001648
#
# Lowest train dice loss at epoch 2300:	0.13978
# Lowest eval  dice loss at epoch 2000:	0.236234
# WARNING: ARGS class initialized.
#
# pi-gan 26-05-2021 05:21:32 cnn setup -1 mapping setup 7
#
# pretrained: None
# pretrained_lr_reset: None
# min_lr not in ARGS
# pcmra_first_omega_0: 30.0
# first_omega_0: 30.0
# translate_max_pixels not in ARGS
# mask_train_cnn: False
# siren_wd: 0
#
# Lowest train mask loss at epoch 2300:	0.020619
# Lowest eval  mask loss at epoch 950:	0.040814
#
# Lowest train pcmra loss at epoch 4900:	0.00125
# Lowest eval  pcmra loss at epoch 2750:	0.001647
#
# Lowest train dice loss at epoch 2300:	0.121081
# Lowest eval  dice loss at epoch 2000:	0.244907
# WARNING: ARGS class initialized.
#
# pi-gan 28-05-2021 12:52:10 cnn setup 14 mapping setup 7 no translation _ great overfitting
#
# pretrained: pi-gan 28-05-2021 12:19:12 cnn setup 14 mapping setup 7 omega_0 100 continue with lr 5e-6
# pretrained_lr_reset: 2e-06
# min_lr not in ARGS
# pcmra_first_omega_0: 100
# first_omega_0: 30.0
# translate_max_pixels not in ARGS
# mask_train_cnn: False
# siren_wd: 0
#
# Lowest train pcmra loss at epoch 250:	0.000382
# Lowest eval  pcmra loss at epoch 0:	0.003808
# WARNING: ARGS class initialized.
#
# pi-gan 29-05-2021 20:17:29 cnn setup -1 mapping setup 7 pcmra omega_0 100 max_pixels 20
#
# pretrained: None
# pretrained_lr_reset: None
# min_lr: 5e-06
# pcmra_first_omega_0: 100
# first_omega_0: 30.0
# translate_max_pixels: 20
# mask_train_cnn: False
# siren_wd: 0
#
# Lowest train mask loss at epoch 3950:	0.026384
# Lowest eval  mask loss at epoch 1050:	0.039495
#
# Lowest train pcmra loss at epoch 5650:	0.00125
# Lowest eval  pcmra loss at epoch 5650:	0.001555
#
# Lowest train dice loss at epoch 3950:	0.14337
# Lowest eval  dice loss at epoch 1900:	0.241739
# WARNING: ARGS class initialized.
#
# pi-gan 30-05-2021 21:01:25 cnn setup -1 mapping setup 7 train mask and cnn together
#
# pretrained: pi-gan 29-05-2021 20:17:29 cnn setup -1 mapping setup 7 pcmra omega_0 100 max_pixels 20
# pretrained_lr_reset: None
# min_lr: 5e-06
# pcmra_first_omega_0: 100
# first_omega_0: 30.0
# translate_max_pixels: 20
# mask_train_cnn: True
# siren_wd: 0
#
# Lowest train mask loss at epoch 3850:	0.025567
# Lowest eval  mask loss at epoch 1450:	0.035153
#
# Lowest train dice loss at epoch 3550:	0.142373
# Lowest eval  dice loss at epoch 3250:	0.213024
# WARNING: ARGS class initialized.
#
# pi-gan 30-05-2021 22:23:19 only train mask _ max translate pixels 8
#
# pretrained: None
# pretrained_lr_reset: None
# min_lr: 5e-06
# pcmra_first_omega_0: 30.0
# first_omega_0: 30.0
# translate_max_pixels: 8
# mask_train_cnn: True
# siren_wd: 0
#
# Lowest train mask loss at epoch 4900:	0.02037
# Lowest eval  mask loss at epoch 3150:	0.031784
#
# Lowest train dice loss at epoch 4900:	0.144234
# Lowest eval  dice loss at epoch 4900:	0.203542
# WARNING: ARGS class initialized.
#
# pi-gan 31-05-2021 01:21:20 siren weight decau 1e-4
#
# pretrained: pi-gan 29-05-2021 20:17:29 cnn setup -1 mapping setup 7 pcmra omega_0 100 max_pixels 20
# pretrained_lr_reset: None
# min_lr: 5e-06
# pcmra_first_omega_0: 100.0
# first_omega_0: 30.0
# translate_max_pixels: 20
# mask_train_cnn: False
# siren_wd: 0.0001
#
# Lowest train mask loss at epoch 4950:	0.023807
# Lowest eval  mask loss at epoch 750:	0.040114
#
# Lowest train dice loss at epoch 4800:	0.126046
# Lowest eval  dice loss at epoch 3000:	0.248818
# WARNING: ARGS class initialized.
#
# pi-gan 31-05-2021 02:15:35 cnn setup -1 mapping setup 7 mask already trained _ now train mask and cnn together
#
# pretrained: pi-gan 29-05-2021 20:17:29 cnn setup -1 mapping setup 7 pcmra omega_0 100 max_pixels 20
# pretrained_lr_reset: None
# min_lr: 5e-06
# pcmra_first_omega_0: 100
# first_omega_0: 30.0
# translate_max_pixels: 20
# mask_train_cnn: True
# siren_wd: 0
#
# Lowest train mask loss at epoch 1850:	0.024559
# Lowest eval  mask loss at epoch 200:	0.04274
#
# Lowest train dice loss at epoch 1850:	0.134394
# Lowest eval  dice loss at epoch 1850:	0.236503
# WARNING: ARGS class initialized.
#
# pi-gan 31-05-2021 04:51:43 cnn setup -1 mapping setup 7 only train mask, no pcmra reconstruction
#
# pretrained: None
# pretrained_lr_reset: None
# min_lr: 5e-06
# pcmra_first_omega_0: 100
# first_omega_0: 30.0
# translate_max_pixels: 20
# mask_train_cnn: True
# siren_wd: 0
#
# Lowest train mask loss at epoch 3650:	0.022993
# Lowest eval  mask loss at epoch 2200:	0.030575
#
# Lowest train dice loss at epoch 3900:	0.123668
# Lowest eval  dice loss at epoch 3700:	0.192891
# WARNING: ARGS class initialized.
#
# pi-gan 31-05-2021 21:19:11 cnn setup -1 mapping setup 7 only train mask, no pcmra reconstruction omega 30
#
# pretrained: None
# pretrained_lr_reset: None
# min_lr: 5e-06
# pcmra_first_omega_0: 30
# first_omega_0: 30.0
# translate_max_pixels: 20
# mask_train_cnn: True
# siren_wd: 0
#
# Lowest train mask loss at epoch 4600:	0.022672
# Lowest eval  mask loss at epoch 3100:	0.031821
#
# Lowest train dice loss at epoch 4850:	0.118449
# Lowest eval  dice loss at epoch 4650:	0.189392
