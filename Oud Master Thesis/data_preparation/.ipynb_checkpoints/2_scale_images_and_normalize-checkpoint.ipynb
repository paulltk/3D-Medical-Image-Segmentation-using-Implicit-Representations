# %%
import numpy as np 
import os 
import matplotlib.pyplot as plt
from scipy.ndimage import zoom

# %%
root = "/home/ptenkaate/scratch/Data/"
projects =  ["Aorta Volunteers", "Aorta BaV", "Aorta Resvcue", "Aorta CoA"]

save_to = "/home/ptenkaate/scratch/Master-Thesis/Dataset"

correct_shape = (128, 128, 24)

scale = (0.5, 0.5, 1)

for project in projects: 
    print(project)
    p_path = os.path.join(root, project, "pcmra")
    m_path = os.path.join(root, project, "mask")
    
    for subject in os.listdir(p_path): 
        pcmra = np.load(os.path.join(p_path, subject))
        try: 
            mask = np.load(os.path.join(m_path, subject))
        except: 
            continue
        
        if pcmra.shape != mask.shape:
            continue

        subject = subject
        print(subject)
        
        pcmra = pcmra / pcmra.max()
        mask = mask / mask.max()
        
        r_string = ""
        if pcmra.shape != correct_shape: 
            resize = tuple([i/ j for i, j in zip(correct_shape, pcmra.shape)])
            
            pcmra = zoom(pcmra, resize)
            mask = zoom(mask, resize)
            
            resize = tuple([round(i, 1) for i in list(resize)])
            r_string = " resized" + str(resize) 
        
        p_name = f"{subject}__{project}__original{r_string}__pcmra.npy"
        m_name = f"{subject}__{project}__original{r_string}__mask.npy"
        
        np.save(os.path.join(save_to, "original_normalized", p_name), pcmra.astype(np.float16))
        np.save(os.path.join(save_to, "original_normalized", m_name), mask.astype(np.float16))
        
        #### save scaled images ####
        small_pcmra = zoom(pcmra, scale)
        small_mask = np.round(zoom(mask, scale))
        
        small_p_name = f"{subject}__{project}__scaled{r_string}__pcmra.npy"
        small_m_name = f"{subject}__{project}__scaled{r_string}__mask.npy"
            
        np.save(os.path.join(save_to, "scaled_normalized", small_p_name), small_pcmra.astype(np.float16))
        np.save(os.path.join(save_to, "scaled_normalized", small_m_name), small_mask.astype(np.float16))
# Out:
# Aorta Volunteers
# 16-01-14_Kerry_kt-pca_done2.npy
# 16-01-22_Jarik_kt-pca_done2.npy
# 16-01-27 Valentine kt-pca_done2.npy
# 16-01-27_Claudia_kt-pca_done2.npy
# 16-02-03_Feiko_kt-pca_done2.npy
# 16-02-10_Luuk_kt-pca_done2.npy
# 16-02-10_Michelle_kt-pca_done.npy
# 16-02-12_Kira_kt-pca_done2.npy
# 16-02-12_Marjolein_kt-pca_done.npy
# 16-03-11_Mart_kt-pca_done.npy
# 16-03-18_Eva_kt-pca_done2.npy
# 16-03-18_Ruud_kt-pca_done2.npy
# 16-03-18_Sanjay2_kt-pca_done2.npy
# 16-04-13_Pim_kt-pca_done2.npy
# 16-05-11 Sandra_kt-pca_done2.npy
# 16-05-25_Emile_kt-pca_done.npy
# 16-06-08_Paul_kt-pca_done2.npy
# 16-06-08_Sevink_kt-pca_done2.npy
# 16-06-17_Planken_kt-pca_done.npy
# 16-06-22_vanKesteren_kt_pca_done2.npy
# 16-06-24_Irma_kt-pca_done1.npy
# 16-06-24_Ot_kt-pca_done1.npy
# 16-12-14_Marcelle_done2.npy
# 17-02-03_Nijveld.npy
# 17-02-08_VaderUiterwijk.npy
# 17-03-15_GJ_Romeijn.npy
# Aorta BaV
# 16-03-23_101_done.npy
# 16-04-13_104_done.npy
# 16-04-13_106_done.npy
# 16-04-20_105_done.npy
# 16-04-20_107_done.npy
# 16-04-29_102_done.npy
# 16-05-18_108_done.npy
# 16-05-25_109_done.npy
# 16-06-03_111_done.npy
# 16-06-22_113_done1.npy
# 16-06-29_115_done1.npy
# 16-06-29_116_done1.npy
# 16-07-15_114_done1.npy
# 16-08-03_100_done1.npy
# 16-08-17_117_done1.npy
# 16-08-19_119_done1.npy
# 16-08-24_120_done1.npy
# 16-08-26_121_done1.npy
# 16-09-02_122_done1.npy
# 16-09-14_124_done1.npy
# 16-09-14_125_done1.npy
# 16-09-28_126_done1.npy
# 16-10-07_127_done1.npy
# Aorta Resvcue
# RESV_001.npy
# RESV_002.npy
# RESV_003.npy
# RESV_004.npy
# RESV_005.npy
# RESV_007.npy
# RESV_008.npy
# RESV_009.npy
# RESV_013.npy
# RESV_015.npy
# RESV_016.npy
# RESV_017.npy
# RESV_020.npy
# RESV_021.npy
# RESV_023.npy
# RESV_025.npy
# RESV_026.npy
# RESV_027.npy
# RESV_028.npy
# RESV_029.npy
# RESV_100.npy
# RESV_101.npy
# RESV_102.npy
# RESV_103.npy
# RESV_104.npy
# RESV_105.npy
# RESV_106.npy
# RESV_107.npy
# RESV_108.npy
# RESV_109.npy
# RESV_110.npy
# RESV_200.npy
