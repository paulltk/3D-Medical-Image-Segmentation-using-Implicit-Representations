# %% [markdown]
# #### Colab run

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
cd drive/MyDrive/master_thesis/pi-gan_sequential
# Out:
# /content/drive/.shortcut-targets-by-id/16udig9ZMaNcASs5Maj6kv7tg-TL3PnSE/Master Thesis/pi-gan_sequential

# %%
# !pip install kornia
# !pip install torchinfo
# Out:
# Requirement already satisfied: kornia in /usr/local/lib/python3.7/dist-packages (0.5.6)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from kornia) (1.9.0+cu102)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->kornia) (3.7.4.3)
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.7/dist-packages (1.5.2)

# %% [markdown]
# #### End Colab run

# %%
import warnings
import time

from py_files.args import *

from py_files.functions import *

from py_files.dataset import *

from py_files.cnn_model import *
from py_files.pigan_model import *

from py_files.load_utils import *
from py_files.data_utils import *
from py_files.plot_utils import *
from py_files.loss_utils import *
from py_files.train_utils import *
from py_files.save_utils import *
# Out:
# Imported CNN and Mapping functions.

# %% [markdown]
# #### Train the model

# %%
def train():  
    
    warnings.filterwarnings("ignore")
    
    ##### path to wich the model should be saved #####
    path = get_folder(ARGS)
    DEVICE = set_device(ARGS)
    
    with open(os.path.join(path, "ARGS.txt"), "w") as f:
        print(vars(ARGS), file=f)
        
    ##### data preparation #####
    train_dl, val_dl, test_dl = initialize_dataloaders(ARGS, DEVICE)
    print("train batch:", next(iter(train_dl))[1][:5])
    print("eval batch:", next(iter(val_dl))[1][:5])
    print("test batch:", next(iter(test_dl))[1][:5])
            
    ##### initialize models and optimizers #####
    models, optims, schedulers = initialize_models_and_optims(ARGS, DEVICE)
    
    blur_layer = initialize_blurring_layer(1.0, DEVICE)
    
    ##### load pretrained model #####
    load_from_saved_run(models, optims, DEVICE, ARGS)

    ##### loss function #####
    if not ARGS.sdf: 
        mask_criterion = nn.BCELoss()
    elif ARGS.sdf:
        mask_criterion = sdf_loss
    else: 
        raise(Exception("Choose a loss function"))   
          
    ##### epoch, train loss mean, train loss std, val loss mean, val loss std #####
    mask_losses, pcmra_losses, dice_losses = np.empty((0, 5)), np.empty((0, 5)), np.empty((0, 5))
    
    for ep in range(ARGS.pcmra_epochs):
    
        t = time.time() 

        for model in models.values():
            model.train()

        loss, _ = train_model(train_dl, models, optims, schedulers, nn.MSELoss(), blur_layer, ARGS, output="pcmra")
        
        if ep % ARGS.eval_every == 0: 

            print(f"Epoch {ep} took {round(time.time() - t, 2)} seconds.")
            
            t_pcmra_mean, t_pcmra_std, _, _ = \
                val_model(train_dl, models, nn.MSELoss(), blur_layer, ARGS, output="pcmra")
            v_pcmra_mean, v_pcmra_std, _, _ = \
                val_model(val_dl, models, nn.MSELoss(), ARGS, output="pcmra")

            pcmra_losses = np.append(pcmra_losses, [[ep ,t_pcmra_mean, t_pcmra_std, 
                                         v_pcmra_mean, v_pcmra_std]], axis=0)
            
            save_loss(path, pcmra_losses, models, optims, name="pcmra_loss", 
                      save_models=True)
        
    
    for ep in range(ARGS.mask_epochs):
    
        t = time.time() 

        for model in models.values():
            model.train()

        loss, _ = train_model(train_dl, models, optims, schedulers, mask_criterion, blur_layer, ARGS, output="mask")
        
        print(f"Epoch {ep}, train loss {loss.round(5)}")
        if ep % ARGS.eval_every == 0: 

            print(f"Epoch {ep} took {round(time.time() - t, 2)} seconds.")
            
            t_mask_mean, t_mask_std, t_dice_mean, t_dice_std = \
                val_model(train_dl, models, nn.BCELoss(), blur_layer, ARGS, output="mask")
            v_mask_mean, v_mask_std, v_dice_mean, v_dice_std = \
                val_model(val_dl, models, nn.BCELoss(), blur_layer, ARGS, output="mask")

            mask_losses = np.append(mask_losses, [[ep ,t_mask_mean, t_mask_std, 
                                         v_mask_mean, v_mask_std]], axis=0)
            dice_losses = np.append(dice_losses, [[ep ,t_dice_mean, t_dice_std, 
                                         v_dice_mean, v_dice_std]], axis=0)
            
            save_loss(path, mask_losses, models, optims, name="mask_loss", 
                      save_models=True)
            save_loss(path, dice_losses, models, optims, name="dice_loss", 
                      save_models=True)

# %% [markdown]
# ## Run as .ipynb

# %%
for i in range(1):

    ARGS = init_ARGS()
    
    ARGS.print_models = True 

    ARGS.mask_epochs = 2000
    ARGS.eval_every = 50    
     
    ARGS.pcmra_epochs = 0
    
    ARGS.patience = 40 
    
    ARGS.first_omega_0 = 300

    ARGS.flip = False 
    ARGS.crop = True 
    ARGS.rotate = True 
    ARGS.translate = True

    ARGS.sdf = True 
    ARGS.sdf_split = 0.5
    ARGS.mask_siren_final_activation = None
    
    ARGS.lambda_sdf = 3e2
    ARGS.lambda_inter = 5e1

    print(vars(ARGS))

    train()  

    torch.cuda.empty_cache()
# Out:
# WARNING: ARGS class initialized.
# {'device': 'GPU', 'print_models': True, 'name': '', 'pretrained': None, 'pretrained_best_dataset': 'train', 'pretrained_best_loss': 'mask', 'pretrained_models': None, 'pretrained_lr_reset': None, 'dataset': 'new', 'seed': 34, 'n_coords_sample': 5000, 'rotate': True, 'translate': True, 'translate_max_pixels': 20, 'flip': False, 'crop': True, 'stretch': True, 'stretch_factor': 1.2, 'norm_min_max': [0, 1], 'pcmra_epochs': 0, 'mask_epochs': 2000, 'batch_size': 24, 'eval_every': 50, 'shuffle': True, 'min_lr': 1e-05, 'patience': 40, 'cnn_setup': -1, 'pcmra_train_cnn': True, 'mask_train_cnn': True, 'cnn_lr': 0.0001, 'cnn_wd': 0, 'mapping_setup': -1, 'mapping_lr': 0.0001, 'pcmra_mapping_lr': 0.0001, 'dim_hidden': 256, 'siren_hidden_layers': 3, 'first_omega_0': 300, 'hidden_omega_0': 30.0, 'siren_lr': 0.0001, 'siren_wd': 0, 'pcmra_first_omega_0': 30.0, 'pcmra_hidden_omega_0': 30.0, 'pcmra_siren_lr': 0.0001, 'pcmra_siren_wd': 0, 'sdf': True, 'sdf_split': 0.5, 'mask_siren_final_activation': None, 'lambda_sdf': 300.0, 'lambda_inter': 50.0, 'lambda_normal': 10.0, 'lambda_grad': 5.0}
# saved_runs/pi_gan_2021_07_16_08_01_11
# ----------------------------------
# Using device for training: cuda
# ----------------------------------
# Train subjects: 86
# Val subjects: 29
# Test subjects: 29
# train batch: ('14', '104', '102', '70', '73')
# eval batch: ('119', '111', '118', '132', '127')
# test batch: ('105', '113', '109', '120', '116')
# CNN
# LargeCNN1(
#   (model): Sequential(
#     (0): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(1, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (1): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(8, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((24, 128, 128), eps=1e-05, elementwise_affine=True)
#         (3): MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#     (2): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(8, 16, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (3): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(16, 16, kernel_size=(5, 5, 5), stride=(1, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((24, 32, 32), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (4): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(16, 32, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (5): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(32, 32, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((12, 16, 16), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (6): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(32, 64, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (7): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(64, 64, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((6, 8, 8), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (8): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(64, 128, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (9): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(128, 128, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#   )
# )
# MAPPING
# LargeMapping1(
#   (gammas): ModuleList(
#     (0): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (1): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (2): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (3): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#   )
#   (betas): ModuleList(
#     (0): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (1): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (2): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (3): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#   )
# )
# SIREN
# Siren(
#   (net): ModuleList(
#     (0): SineLayer(
#       (linear): Linear(in_features=3, out_features=256, bias=True)
#     )
#     (1): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (2): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (3): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (final_linear): Linear(in_features=256, out_features=1, bias=True)
# )
# PCMRA_MAPPING
# LargeMapping1(
#   (gammas): ModuleList(
#     (0): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (1): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (2): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (3): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#   )
#   (betas): ModuleList(
#     (0): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (1): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (2): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (3): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#   )
# )
# PCMRA_SIREN
# Siren(
#   (net): ModuleList(
#     (0): SineLayer(
#       (linear): Linear(in_features=3, out_features=256, bias=True)
#     )
#     (1): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (2): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (3): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (final_linear): Linear(in_features=256, out_features=1, bias=True)
# )
# Epoch 0, train loss 16.37672
# Epoch 0 took 4.31 seconds.
# mask_loss       Train: 0.681907, 	 Eval: 0.681929
# New best train loss, saving model.
# New best eval  loss, saving model.
# dice_loss       Train: 1.000000, 	 Eval: 1.000000
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 1, train loss 15.1392
# Epoch 2, train loss 14.62196
# Epoch 3, train loss 14.5503
# Epoch 4, train loss 14.44668
# Epoch 5, train loss 14.42894
# Epoch 6, train loss 14.37742
# Epoch 7, train loss 14.22301
# Epoch 8, train loss 14.1504
# Epoch 9, train loss 13.95016
# Epoch 10, train loss 13.36896
# Epoch 11, train loss 14.62537
# Epoch 12, train loss 14.20842
# Epoch 13, train loss 13.87487
# Epoch 14, train loss 13.80443
# Epoch 15, train loss 13.0955
# Epoch 16, train loss 13.1422
# Epoch 17, train loss 12.8398
# Epoch 18, train loss 12.9139
# Epoch 19, train loss 12.8861
# Epoch 20, train loss 12.96019
# Epoch 21, train loss 12.8758
# Epoch 22, train loss 12.80046
# Epoch 23, train loss 12.55828
# Epoch 24, train loss 12.4827
# Epoch 25, train loss 12.3675
# Epoch 26, train loss 12.0694
# Epoch 27, train loss 11.91957
# Epoch 28, train loss 11.63497
# Epoch 29, train loss 11.69064
# Epoch 30, train loss 11.68386
# Epoch 31, train loss 11.36176
# Epoch 32, train loss 11.57298
# Epoch 33, train loss 11.47206
# Epoch 34, train loss 11.49239
# Epoch 35, train loss 11.33394
# Epoch 36, train loss 11.41848
# Epoch 37, train loss 11.24139
# Epoch 38, train loss 11.22626
# Epoch 39, train loss 11.26057
# Epoch 40, train loss 11.35656
# Epoch 41, train loss 11.28089
# Epoch 42, train loss 11.41003
# Epoch 43, train loss 11.32741
# Epoch 44, train loss 11.1738
# Epoch 45, train loss 10.96694
# Epoch 46, train loss 10.97515
# Epoch 47, train loss 10.94103
# Epoch 48, train loss 11.12795
# Epoch 49, train loss 11.10022
# Epoch 50, train loss 11.03189
# Epoch 50 took 4.76 seconds.
# mask_loss       Train: 0.620416, 	 Eval: 0.619474
# New best train loss, saving model.
# New best eval  loss, saving model.
# dice_loss       Train: 0.997670, 	 Eval: 1.000000
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 51, train loss 10.76649
# Epoch 52, train loss 10.61041
# Epoch 53, train loss 10.74117
# Epoch 54, train loss 10.52136
# Epoch 55, train loss 10.64211
# Epoch 56, train loss 10.4972
# Epoch 57, train loss 10.35628
# Epoch 58, train loss 10.5901
# Epoch 59, train loss 10.50024
# Epoch 60, train loss 10.52975
# Epoch 61, train loss 10.0618
# Epoch 62, train loss 10.4484
# Epoch 63, train loss 10.3027
# Epoch 64, train loss 10.26044
# Epoch 65, train loss 10.52824
# Epoch 66, train loss 10.08331
# Epoch 67, train loss 10.33537
# Epoch 68, train loss 10.27244
# Epoch 69, train loss 10.17541
# Epoch 70, train loss 10.48557
# Epoch 71, train loss 10.33866
# Epoch 72, train loss 9.89668
# Epoch 73, train loss 9.88196
# Epoch 74, train loss 9.83628
# Epoch 75, train loss 9.52956
# Epoch 76, train loss 9.91443
# Epoch 77, train loss 10.0825
# Epoch 78, train loss 9.95768
# Epoch 79, train loss 9.89584
# Epoch 80, train loss 9.57922
# Epoch 81, train loss 9.88252
# Epoch 82, train loss 9.73937
# Epoch 83, train loss 9.88206
# Epoch 84, train loss 9.54131
# Epoch 85, train loss 9.95435
# Epoch 86, train loss 9.79079
# Epoch 87, train loss 9.61706
# Epoch 88, train loss 9.934
# Epoch 89, train loss 9.84785
# Epoch 90, train loss 10.09917
# Epoch 91, train loss 9.93311
# Epoch 92, train loss 9.87442
# Epoch 93, train loss 9.47945
# Epoch 94, train loss 9.72727
# Epoch 95, train loss 9.65521
# Epoch 96, train loss 9.39171
# Epoch 97, train loss 9.50507
# Epoch 98, train loss 9.89097
# Epoch 99, train loss 9.72514
# Epoch 100, train loss 9.79068
# Epoch 100 took 4.77 seconds.
# mask_loss       Train: 0.584294, 	 Eval: 0.587031
# New best train loss, saving model.
# New best eval  loss, saving model.
# dice_loss       Train: 0.629408, 	 Eval: 0.672815
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 101, train loss 9.74733
# Epoch 102, train loss 9.4748
# Epoch 103, train loss 9.60921
# Epoch 104, train loss 9.36329
# Epoch 105, train loss 9.61255
# Epoch 106, train loss 9.42782
# Epoch 107, train loss 9.6716
# Epoch 108, train loss 9.62984
# Epoch 109, train loss 9.55524
# Epoch 110, train loss 9.76794
# Epoch 111, train loss 9.63295
# Epoch 112, train loss 9.66407
# Epoch 113, train loss 9.52148
# Epoch 114, train loss 9.21353
# Epoch 115, train loss 9.12311
# Epoch 116, train loss 9.2323
# Epoch 117, train loss 9.27682
# Epoch 118, train loss 8.96495
# Epoch 119, train loss 9.10099
# Epoch 120, train loss 8.92175
# Epoch 121, train loss 8.82815
# Epoch 122, train loss 9.20786
# Epoch 123, train loss 9.34948
# Epoch 124, train loss 9.04379
# Epoch 125, train loss 9.2093
# Epoch 126, train loss 9.14134
# Epoch 127, train loss 9.17159
# Epoch 128, train loss 9.23413
# Epoch 129, train loss 9.29324
# Epoch 130, train loss 9.27683
# Epoch 131, train loss 9.4208
# Epoch 132, train loss 9.07702
# Epoch 133, train loss 9.09762
# Epoch 134, train loss 9.10544
# Epoch 135, train loss 8.87808
# Epoch 136, train loss 8.76328
# Epoch 137, train loss 9.04719
# Epoch 138, train loss 9.00829
# Epoch 139, train loss 8.98184
# Epoch 140, train loss 8.64475
# Epoch 141, train loss 8.7834
# Epoch 142, train loss 8.70887
# Epoch 143, train loss 8.77833
# Epoch 144, train loss 8.79333
# Epoch 145, train loss 9.07033
# Epoch 146, train loss 8.98526
# Epoch 147, train loss 9.15556
# Epoch 148, train loss 9.16588
# Epoch 149, train loss 9.17015
# Epoch 150, train loss 9.31976
# Epoch 150 took 4.75 seconds.
# mask_loss       Train: 0.534941, 	 Eval: 0.537590
# New best train loss, saving model.
# New best eval  loss, saving model.
# dice_loss       Train: 0.545218, 	 Eval: 0.539624
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 151, train loss 9.16965
# Epoch 152, train loss 9.31716
# Epoch 153, train loss 9.07001
# Epoch 154, train loss 8.82795
# Epoch 155, train loss 8.70918
# Epoch 156, train loss 8.8125
# Epoch 157, train loss 8.7191
# Epoch 158, train loss 8.67512
# Epoch 159, train loss 8.54489
# Epoch 160, train loss 8.76766
# Epoch 161, train loss 8.56604
# Epoch 162, train loss 8.3929
# Epoch 163, train loss 8.31653
# Epoch 164, train loss 8.37016
# Epoch 165, train loss 8.47814
# Epoch 166, train loss 8.53881
# Epoch 167, train loss 8.55989
# Epoch 168, train loss 8.67374
# Epoch 169, train loss 8.82696
# Epoch 170, train loss 8.74834
# Epoch 171, train loss 9.01057
# Epoch 172, train loss 8.64417
# Epoch 173, train loss 8.49165
# Epoch 174, train loss 8.65628
# Epoch 175, train loss 8.54169
# Epoch 176, train loss 8.39312
# Epoch 177, train loss 8.46729
# Epoch 178, train loss 8.34889
# Epoch 179, train loss 8.31326
# Epoch 180, train loss 8.20118
# Epoch 181, train loss 8.47071
# Epoch 182, train loss 8.6636
# Epoch 183, train loss 8.36716
# Epoch 184, train loss 8.47886
# Epoch 185, train loss 8.58759
# Epoch 186, train loss 8.58902
# Epoch 187, train loss 8.57366
# Epoch 188, train loss 8.51041
# Epoch 189, train loss 8.65628
# Epoch 190, train loss 8.66641
# Epoch 191, train loss 8.76948
# Epoch 192, train loss 8.58021
# Epoch 193, train loss 8.55922
# Epoch 194, train loss 8.64443
# Epoch 195, train loss 8.2667
# Epoch 196, train loss 8.1287
# Epoch 197, train loss 8.13203
# Epoch 198, train loss 8.28499
# Epoch 199, train loss 8.13181
# Epoch 200, train loss 8.38922
# Epoch 200 took 4.75 seconds.
# mask_loss       Train: 0.541758, 	 Eval: 0.543599
# dice_loss       Train: 0.815397, 	 Eval: 0.765793
# Epoch 201, train loss 8.09955
# Epoch 202, train loss 8.22977
# Epoch 203, train loss 8.181
# Epoch 204, train loss 8.22415
# Epoch 205, train loss 8.30432
# Epoch 206, train loss 8.44314
# Epoch 207, train loss 8.44542
# Epoch 208, train loss 8.4619
# Epoch 292, train loss 7.39432
# Epoch 293, train loss 7.4434
# Epoch 294, train loss 7.43904
# Epoch 295, train loss 7.74149
# Epoch 296, train loss 7.45917
# Epoch 297, train loss 7.61899
# Epoch 298, train loss 7.70546
# Epoch 299, train loss 7.45842
# Epoch 300, train loss 7.45008
# Epoch 300 took 4.75 seconds.
# mask_loss       Train: 0.571323, 	 Eval: 0.575756
# dice_loss       Train: 0.899233, 	 Eval: 0.905257
# Epoch 301, train loss 7.67881
# Epoch 302, train loss 7.66655
# Epoch 303, train loss 7.49256
# Epoch 304, train loss 7.46684
# Epoch 305, train loss 7.37884
# Epoch 306, train loss 7.24486
# Epoch 307, train loss 7.3728
# Epoch 308, train loss 7.29203
# Epoch 309, train loss 7.38392
# Epoch 310, train loss 7.38774
# Epoch 311, train loss 7.30821
# Epoch 312, train loss 7.18969
# Epoch 313, train loss 7.32591
# Epoch 314, train loss 7.51336
# Epoch 315, train loss 7.55306
# Epoch 316, train loss 7.58479
# Epoch 317, train loss 7.36268
# Epoch 318, train loss 7.39883
# Epoch 319, train loss 7.40986
# Epoch 320, train loss 7.43638
# Epoch 321, train loss 7.2832
# Epoch 322, train loss 7.33734
# Epoch 323, train loss 7.17777
# Epoch 324, train loss 7.58475
# Epoch 325, train loss 7.57446
# Epoch 326, train loss 7.30045
# Epoch 327, train loss 7.1209
# Epoch 328, train loss 7.36952
# Epoch 329, train loss 7.49635
# Epoch 330, train loss 7.5011
# Epoch 331, train loss 7.43757
# Epoch 332, train loss 7.07679
# Epoch 333, train loss 7.38824
# Epoch 334, train loss 7.41332
# Epoch 335, train loss 7.38292
# Epoch 336, train loss 7.42034
# Epoch 337, train loss 7.47413
# Epoch 338, train loss 7.36272
# Epoch 339, train loss 7.44072
# Epoch 340, train loss 7.44879
# Epoch 341, train loss 7.24587
# Epoch 342, train loss 7.2177
# Epoch 343, train loss 7.41332
# Epoch 344, train loss 7.42247
# Epoch 345, train loss 7.22896
# Epoch 346, train loss 7.16517
# Epoch 347, train loss 7.27668
# Epoch 348, train loss 7.074
# Epoch 349, train loss 7.0203
# Epoch 350, train loss 7.168
# Epoch 350 took 4.76 seconds.
# mask_loss       Train: 0.532585, 	 Eval: 0.537955
# New best train loss, saving model.
# dice_loss       Train: 0.353879, 	 Eval: 0.375992
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 351, train loss 7.24154
# Epoch 352, train loss 7.22037
# Epoch 353, train loss 7.17828
# Epoch 354, train loss 7.2031
# Epoch 355, train loss 7.02642
# Epoch 356, train loss 7.17406
# Epoch 357, train loss 7.03976
# Epoch 358, train loss 7.04184
# Epoch 359, train loss 7.08159
# Epoch 360, train loss 6.91574
# Epoch 361, train loss 6.85816
# Epoch 362, train loss 6.94649
# Epoch 363, train loss 6.88031
# Epoch 364, train loss 7.09489
# Epoch 365, train loss 7.05742
# Epoch 366, train loss 7.31316
# Epoch 367, train loss 7.17549
# Epoch 368, train loss 7.12969
# Epoch 369, train loss 6.98109
# dice_loss       Train: 0.345149, 	 Eval: 0.354168
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 451, train loss 6.69083
# Epoch 452, train loss 6.82867
# Epoch 453, train loss 6.78184
# Epoch 454, train loss 6.87799
# Epoch 455, train loss 6.59106
# Epoch 456, train loss 6.66203
# Epoch 457, train loss 6.88048
# Epoch 458, train loss 6.69948
# Epoch 459, train loss 6.7893
# Epoch 460, train loss 6.93252
# Epoch 461, train loss 6.75669
# Epoch 462, train loss 6.80616
# Epoch 463, train loss 6.82816
# Epoch 464, train loss 7.03669
# Epoch 465, train loss 6.92582
# Epoch 466, train loss 6.80781
# Epoch 467, train loss 6.81658
# Epoch 468, train loss 6.76299
# Epoch 469, train loss 6.8343
# Epoch 470, train loss 6.66744
# Epoch 471, train loss 6.5413
# Epoch 472, train loss 6.77282
# Epoch 473, train loss 6.82598
# Epoch 474, train loss 6.59386
# Epoch 475, train loss 6.70364
# Epoch 476, train loss 6.66416
# Epoch 477, train loss 6.6075
# Epoch 478, train loss 6.57525
# Epoch 479, train loss 6.63168
# Epoch 480, train loss 6.68318
# Epoch 481, train loss 6.5314
# Epoch 482, train loss 6.55455
# Epoch 483, train loss 6.62016
# Epoch 484, train loss 6.56652
# Epoch   486: reducing learning rate of group 0 to 5.0000e-05.
# Epoch   486: reducing learning rate of group 0 to 5.0000e-05.
# Epoch   486: reducing learning rate of group 0 to 5.0000e-05.
# Epoch 485, train loss 6.51866
# Epoch 486, train loss 6.61384
# Epoch 487, train loss 6.55106
# Epoch 488, train loss 6.56544
# Epoch 489, train loss 6.30842
# Epoch 490, train loss 6.1663
# Epoch 491, train loss 6.49732
# Epoch 492, train loss 6.30049
# Epoch 493, train loss 6.398
# Epoch 494, train loss 6.16514
# Epoch 495, train loss 6.39669
# Epoch 496, train loss 6.42984
# Epoch 497, train loss 6.36911
# Epoch 498, train loss 6.37173
# Epoch 499, train loss 6.25733
# Epoch 500, train loss 6.19907
# Epoch 500 took 4.73 seconds.
# mask_loss       Train: 0.522947, 	 Eval: 0.529096
# New best train loss, saving model.
# New best eval  loss, saving model.
# dice_loss       Train: 0.276022, 	 Eval: 0.287611
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 501, train loss 6.31691
# Epoch 502, train loss 6.29656
# Epoch 503, train loss 6.36276
# Epoch 504, train loss 6.16681
# Epoch 505, train loss 6.47633
# Epoch 506, train loss 6.33313
# Epoch 507, train loss 6.35932
# Epoch 508, train loss 6.22411
# Epoch 509, train loss 6.1793
# Epoch 510, train loss 6.30539
# Epoch 511, train loss 6.39956
# Epoch 512, train loss 6.28648
# Epoch 513, train loss 6.19914
# Epoch 514, train loss 6.3821
# Epoch 515, train loss 6.3361
# Epoch 516, train loss 6.48652
# Epoch 517, train loss 6.52248
# Epoch 518, train loss 6.34825
# Epoch 519, train loss 6.32116
# Epoch 520, train loss 6.32463
# Epoch 521, train loss 6.23635
# Epoch 522, train loss 6.31031
# Epoch 523, train loss 6.28473
# Epoch 1304, train loss 5.65759
# Epoch 1305, train loss 5.56507
# Epoch 1306, train loss 5.6522
# Epoch 1307, train loss 5.6778
# Epoch 1308, train loss 5.68201
# Epoch 1309, train loss 5.61586
# Epoch 1310, train loss 5.56299
# Epoch 1311, train loss 5.67539
# Epoch 1312, train loss 5.50765
# Epoch 1313, train loss 5.6377
# Epoch 1314, train loss 5.62585
# Epoch 1315, train loss 5.69043
# Epoch 1316, train loss 5.73636
# Epoch 1317, train loss 5.57121
# Epoch 1318, train loss 5.63607
# Epoch 1319, train loss 5.67306
# Epoch 1320, train loss 5.65147
# Epoch 1321, train loss 5.64813

# %% [markdown]
# ## Run as .py

# %%
# def str2bool(v):
#     if isinstance(v, bool):
#         return v
#     if v.lower() in ('yes', 'true', 't', 'y', '1'):
#         return True
#     elif v.lower() in ('no', 'false', 'f', 'n', '0'):
#         return False
#     else:
#         raise argparse.ArgumentTypeError('Boolean value expected.')

# if __name__ == "__main__":

#     PARSER = argparse.ArgumentParser()

    
#     # Arguments for training
#     PARSER.add_argument('--device', type=str, default="GPU", 
#                         help='Device that should be used.')

#     PARSER.add_argument('--print_models', type=str2bool, nargs="?", const=True, default=False, 
#                         help='Print the models after initialization or not.')

#     PARSER.add_argument('--name', type=str, default="", 
#                         help='Name of the folder where the output should be saved.')
    
    

#     # pretrained params 
    
#     PARSER.add_argument('--pretrained', type=str, default=None, 
#                         help='Folder name of pretrained model that should be loaded.')
    
#     PARSER.add_argument('--pretrained_best_dataset', type=str, default="train", 
#                         help='Pretrained model with lowest [train, val] loss.')
    
#     PARSER.add_argument('--pretrained_best_loss', type=str, default="mask", 
#                         help='Pretrained model with lowest [train, val] loss.')
    
#     PARSER.add_argument('--pretrained_models', type=str, default=None, 
#                         help='Choose which pretrained models to load. None = all models')
    
#     PARSER.add_argument('--pretrained_lr_reset', type=str, default=None, 
#                         help='Reset the lr to a value.')
    
    
    
#     # data
#     PARSER.add_argument('--dataset', type=str, default="new", 
#                         help='The dataset which we train on.')
    
#     PARSER.add_argument('--seed', type=int, default=34, 
#                         help='Seed for initializig dataloader')
    
#     PARSER.add_argument('--rotate', type=str2bool, nargs="?", const=True, default=True, 
#                         help='Rotations of the same image')
    
#     PARSER.add_argument('--translate', type=str2bool, nargs="?", const=True, default=True, 
#                         help='Translations of the same image')
    
#     PARSER.add_argument('--translate_max_pixels', type=int, default=20, 
#                         help='Translation max in height and width.')
    
#     PARSER.add_argument('--flip', type=str2bool, nargs="?", const=True, default=True, 
#                         help='Flips the train image')
    
#     PARSER.add_argument('--crop', type=str2bool, nargs="?", const=True, default=True, 
#                         help='Crops the train image')

#     PARSER.add_argument('--stretch', type=str2bool, nargs="?", const=True, default=True, 
#                         help='Stretches the train image')

#     PARSER.add_argument('--stretch_factor', type=float, default=1.2, 
#                         help='Stretch maximum of the train image')

#     PARSER.add_argument('--norm_min_max', type=list, default=[0, 1], 
#                         help='List with min and max for normalizing input.')
    
    
    
#     # train variables
#     PARSER.add_argument('--pcmra_epochs', type=int, default=5000, 
#                         help='Number of epochs for pcmra training.')

#     PARSER.add_argument('--mask_epochs', type=int, default=5000, 
#                         help='Number of epochs for mask training.')
    
#     PARSER.add_argument('--batch_size', type=int, default=24, 
#                         help='Number of epochs.')
        
#     PARSER.add_argument('--eval_every', type=int, default=50, 
#                         help='Set the # epochs after which evaluation should be done.')
    
#     PARSER.add_argument('--shuffle', type=str2bool, nargs="?", const=True, default=True, 
#                         help='Shuffle the train dataloader?')
    
#     PARSER.add_argument('--n_coords_sample', type=int, default=5000, 
#                         help='Number of coordinates that should be sampled for each subject.')
    
#     PARSER.add_argument('--min_lr', type=float, default=1e-5, 
#                         help='Minimum lr, input for lr scheduler.')
    
    
    
#     # CNN
#     PARSER.add_argument('--cnn_setup', type=int, default=-1, 
#                         help='Setup of the CNN.')
    
#     PARSER.add_argument('--pcmra_train_cnn', type=str2bool, nargs="?", const=True, default=True, 
#                         help='Whether to also train the cnn during pcmra reconstruction.')

#     PARSER.add_argument('--mask_train_cnn', type=str2bool, nargs="?", const=True, default=True, 
#                         help='Whether to also train the cnn during mask segmentation.')


    
#     # Mapping
#     PARSER.add_argument('--mapping_setup', type=int, default=-1, 
#                         help='Setup of the Mapping network.')

    
    
#     # SIREN
#     PARSER.add_argument('--dim_hidden', type=int, default=256, 
#                         help='Dimension of hidden SIREN layers.')
    
#     PARSER.add_argument('--siren_hidden_layers', type=int, default=3, 
#                         help='Number of hidden SIREN layers.')
    
    
#     PARSER.add_argument('--first_omega_0', type=float, default=30., 
#                         help='Omega_0 of first layer.')
    
#     PARSER.add_argument('--hidden_omega_0', type=float, default=30., 
#                         help='Omega_0 of hidden layer.')
    
    
#     PARSER.add_argument('--pcmra_first_omega_0', type=float, default=30., 
#                         help='Omega_0 of first layer of PCMRA siren.')
    
#     PARSER.add_argument('--pcmra_hidden_omega_0', type=float, default=30., 
#                         help='Omega_0 of hidden layer of PCMRA siren.')
    
    
    
#     # optimizers
#     PARSER.add_argument('--cnn_lr', type=float, default=1e-4, 
#                         help='Learning rate of cnn optim.')

#     PARSER.add_argument('--cnn_wd', type=float, default=0, 
#                         help='Weight decay of cnn optim.')

    
#     PARSER.add_argument('--mapping_lr', type=float, default=1e-4, 
#                         help='Learning rate of siren optim.')
    
#     PARSER.add_argument('--pcmra_mapping_lr', type=float, default=1e-4, 
#                         help='Learning rate of siren optim.')
    

#     PARSER.add_argument('--siren_lr', type=float, default=1e-4, 
#                         help='Learning rate of siren optim.')

#     PARSER.add_argument('--siren_wd', type=float, default=0, 
#                         help='Weight decay of siren optim.')
    
    
#     PARSER.add_argument('--pcmra_siren_lr', type=float, default=1e-4, 
#                         help='Learning rate of PCMRA siren optim.')    
    
#     PARSER.add_argument('--pcmra_siren_wd', type=float, default=0, 
#                         help='Weight decay of PCMRA siren optim.')
    
#     PARSER.add_argument('--patience', type=int, default=200, 
#                         help='Patience of the LR scheduler.')
    
    
#     ARGS = PARSER.parse_args()
    
#     train()
