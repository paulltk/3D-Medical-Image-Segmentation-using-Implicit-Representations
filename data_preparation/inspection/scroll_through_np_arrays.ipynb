# %%
import torch
import torch.nn.functional as F

from torch import nn
from torch.utils.data import DataLoader, Dataset
from torchvision.transforms import Resize, Compose, ToTensor, Normalize

import argparse
import os
import math 
import skimage
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import time
import pickle

from datetime import datetime
from pathlib import Path

# from data_classes.py_files.custom_datasets import *

# from model_classes.py_files.cnn_model import *
# from model_classes.py_files.pigan_model import *

# from functions import *

# %matplotlib qt

# %%
root = "/home/ptenkaate/scratch/Master-Thesis/Dataset/original_normalized_rotated"

files = os.listdir(root)
files = sorted([file for file in files if file.split("__")[-1] == "pcmra.npy"])[:100]
print(files)

subjs = []
projs = []
augs = []
pcmras = []
masks = []

for file in files: 
    subj, proj, aug, imtype = file.split("__")
    
    pcmra = np.load(os.path.join(root, f"{subj}__{proj}__{aug}__pcmra.npy"))
    mask = np.load(os.path.join(root, f"{subj}__{proj}__{aug}__mask.npy"))
    
    subjs.append(subj)
    projs.append(proj)
    augs.append(aug)
    pcmras.append(pcmra)
    masks.append(mask)
# Out:
# ['16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot -2 (0, 1)__pcmra.npy', '16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot -2 (0, 2)__pcmra.npy', '16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot -2 (1, 2)__pcmra.npy', '16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot -4 (0, 1)__pcmra.npy', '16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot -4 (0, 2)__pcmra.npy', '16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot -4 (1, 2)__pcmra.npy', '16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot -6 (0, 1)__pcmra.npy', '16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot -6 (0, 2)__pcmra.npy', '16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot -6 (1, 2)__pcmra.npy', '16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot 0 (-, -)__pcmra.npy', '16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot 2 (0, 1)__pcmra.npy', '16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot 2 (0, 2)__pcmra.npy', '16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot 2 (1, 2)__pcmra.npy', '16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot 4 (0, 1)__pcmra.npy', '16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot 4 (0, 2)__pcmra.npy', '16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot 4 (1, 2)__pcmra.npy', '16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot 6 (0, 1)__pcmra.npy', '16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot 6 (0, 2)__pcmra.npy', '16-01-14_Kerry_kt-pca_done2.npy__Aorta Volunteers__original_rot 6 (1, 2)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot -2 (0, 1)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot -2 (0, 2)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot -2 (1, 2)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot -4 (0, 1)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot -4 (0, 2)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot -4 (1, 2)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot -6 (0, 1)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot -6 (0, 2)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot -6 (1, 2)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot 0 (-, -)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot 2 (0, 1)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot 2 (0, 2)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot 2 (1, 2)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot 4 (0, 1)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot 4 (0, 2)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot 4 (1, 2)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot 6 (0, 1)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot 6 (0, 2)__pcmra.npy', '16-01-22_Jarik_kt-pca_done2.npy__Aorta Volunteers__original_rot 6 (1, 2)__pcmra.npy', '16-01-27 Valentine kt-pca_done2.npy__Aorta Volunteers__original_rot -2 (0, 1)__pcmra.npy', '16-01-27 Valentine kt-pca_done2.npy__Aorta Volunteers__original_rot -2 (0, 2)__pcmra.npy', '16-01-27 Valentine kt-pca_done2.npy__Aorta Volunteers__original_rot -2 (1, 2)__pcmra.npy', '16-01-27 Valentine kt-pca_done2.npy__Aorta Volunteers__original_rot -4 (0, 1)__pcmra.npy', '16-01-27 Valentine kt-pca_done2.npy__Aorta Volunteers__original_rot -4 (0, 2)__pcmra.npy', '16-01-27 Valentine kt-pca_done2.npy__Aorta Volunteers__original_rot -4 (1, 2)__pcmra.npy', '16-01-27 Valentine kt-pca_done2.npy__Aorta Volunteers__original_rot -6 (0, 1)__pcmra.npy', '16-01-27 Valentine kt-pca_done ...

# %%
class Show_images(object):
    """
    Scroll through slices. Takes an unspecified number of subfigures per figure.
    suptitles: either a str or a list. Represents the 
    main title of a figure. 
    images_titles: a list with tuples, each tuple an np.array and a 
    title for the array subfigure. 
    """
    def __init__(self, suptitles, *images_titles, min_max=[0, 1]):
        # if string if given, make list with that title for 
        # each slice.
        if type(suptitles) == str: 
            self.suptitles = []
            for i in range(images_titles[0][0].shape[2]): 
                self.suptitles.append(suptitles)
        else: 
            self.suptitles = suptitles
                    
        self.fig, self.ax = plt.subplots(1,len(images_titles))

        # split tuples with (image, title) into lists
        self.images = [x[0] for x in images_titles]
        self.titles = [x[1] for x in images_titles]

        # get the number of slices that are to be shown
        rows, cols, self.slices = self.images[0].shape        
        self.ind = 0

        self.fig.suptitle(self.suptitles[self.ind]) # set title 

        self.plots = []
        
        # start at slice 10 if more than 20 slices, 
        # otherwise start at middle slice.
        if self.images[0].shape[2] > 20: 
            self.ind = 10
        else:
            self.ind = self.images[0].shape[2] // 2
        
        # make sure ax is an np array
        if type(self.ax) == np.ndarray:
            pass
        else: 
            self.ax = np.array([self.ax])
        
        # create title for each subfigure in slice
        for (sub_ax, image, title) in zip(self.ax, self.images, self.titles): 
            sub_ax.set_title(title)
            plot = sub_ax.imshow(image[:, :, self.ind], vmin=min_max[0], vmax=min_max[1])
            self.plots.append(plot)

            
        # link figure to mouse scroll movement
        self.plot_show = self.fig.canvas.mpl_connect('scroll_event', self.onscroll)
        

    def onscroll(self, event):
        """
        Shows next or previous slice with mouse scroll.
        """
        if event.button == 'up':
            self.ind = (self.ind - 1) % self.slices
        else:
            self.ind = (self.ind + 1) % self.slices
        
        self.update()
        

    def update(self):
        """
        Updates the figure.
        """
        self.fig.suptitle(self.suptitles[self.ind])
        
        for plot, image in zip(self.plots, self.images):
            plot.set_data(image[:, :, self.ind])
        
        self.ax[0].set_ylabel('Slice Number: %s' % self.ind)
        self.plots[0].axes.figure.canvas.draw()

# %%
def show_data(data, shape=(64, 64, 24)):
    
    
    titles = []
    
    pcmras = []
    masks = []
    
    for i in range(len(data[0])):
        subj, proj, aug, pcmra, mask = data[0][i], data[1][i], data[2][i], data[3][i], data[4][i]

        pcmras.append(pcmra.astype(np.float64))
        masks.append(mask.astype(np.float64))
    
        
        titles += [f"{i}: {subj} {proj} {aug}" for slce in range(shape[2])]
    
    pcmras = np.concatenate(pcmras, axis=2)
    masks = np.concatenate(masks, axis=2)
    
    pcmra_masks = pcmras + masks

    return Show_images(titles, (pcmras, "pcmras"), (masks, "masks"))

window = show_data([subjs, projs, augs, pcmras, masks])

# %%
subjects = np.load(f"//home/ptenkaate/scratch/Data/Datasets/Aorta/Small/subjects.npy")

# %%
print(subjects)
# Out:
# [['16-01-14_Kerry_kt-pca_done2' 'Aorta Volunteers']
#  ['16-01-22_Jarik_kt-pca_done2' 'Aorta Volunteers']
#  ['16-01-27 Valentine kt-pca_done2' 'Aorta Volunteers']
#  ['16-01-27_Claudia_kt-pca_done2' 'Aorta Volunteers']
#  ['16-02-03_Feiko_kt-pca_done2' 'Aorta Volunteers']
#  ['16-02-10_Luuk_kt-pca_done2' 'Aorta Volunteers']
#  ['16-02-10_Michelle_kt-pca_done' 'Aorta Volunteers']
#  ['16-02-12_Kira_kt-pca_done2' 'Aorta Volunteers']
#  ['16-02-12_Marjolein_kt-pca_done' 'Aorta Volunteers']
#  ['16-03-11_Mart_kt-pca_done' 'Aorta Volunteers']
#  ['16-03-18_Eva_kt-pca_done2' 'Aorta Volunteers']
#  ['16-03-18_Ruud_kt-pca_done2' 'Aorta Volunteers']
#  ['16-03-18_Sanjay2_kt-pca_done2' 'Aorta Volunteers']
#  ['16-04-13_Pim_kt-pca_done2' 'Aorta Volunteers']
#  ['16-05-11 Sandra_kt-pca_done2' 'Aorta Volunteers']
#  ['16-05-25_Emile_kt-pca_done' 'Aorta Volunteers']
#  ['16-06-17_Planken_kt-pca_done' 'Aorta Volunteers']
#  ['16-06-22_vanKesteren_kt_pca_done2' 'Aorta Volunteers']
#  ['16-06-24_Ot_kt-pca_done1' 'Aorta Volunteers']
#  ['16-12-14_Marcelle_done2' 'Aorta Volunteers']
#  ['17-02-08_VaderUiterwijk' 'Aorta Volunteers']
#  ['16-04-13_104_done' 'Aorta BaV']
#  ['16-04-13_106_done' 'Aorta BaV']
#  ['16-04-20_105_done' 'Aorta BaV']
#  ['16-04-20_107_done' 'Aorta BaV']
#  ['16-04-29_102_done' 'Aorta BaV']
#  ['16-05-25_109_done' 'Aorta BaV']
#  ['16-06-22_113_done1' 'Aorta BaV']
#  ['16-06-29_115_done1' 'Aorta BaV']
#  ['16-06-29_116_done1' 'Aorta BaV']
#  ['16-08-03_100_done1' 'Aorta BaV']
#  ['16-08-24_120_done1' 'Aorta BaV']
#  ['16-08-26_121_done1' 'Aorta BaV']
#  ['16-09-28_126_done1' 'Aorta BaV']
#  ['RESV_001' 'Aorta Resvcue']
#  ['RESV_002' 'Aorta Resvcue']
#  ['RESV_003' 'Aorta Resvcue']
#  ['RESV_004' 'Aorta Resvcue']
#  ['RESV_007' 'Aorta Resvcue']
#  ['RESV_008' 'Aorta Resvcue']
#  ['RESV_013' 'Aorta Resvcue']
#  ['RESV_016' 'Aorta Resvcue']
#  ['RESV_017' 'Aorta Resvcue']
#  ['RESV_021' 'Aorta Resvcue']
#  ['RESV_027' 'Aorta Resvcue']
#  ['RESV_029' 'Aorta Resvcue']
#  ['RESV_100' 'Aorta Resvcue']
#  ['RESV_101' 'Aorta Resvcue']
#  ['RESV_103' 'Aorta Resvcue']
#  ['RESV_104' 'Aorta Resvcue']
#  ['RESV_105' 'Aorta Resvcue']
#  ['RESV_107' 'Aorta Resvcue']
#  ['RESV_109' 'Aorta Resvcue']
#  ['RESV_110' 'Aorta Resvcue']
#  ['RESV_202' 'Aorta Resvcue']
#  ['RESV_203' 'Aorta Resvcue']
#  ['RESV_302' 'Aorta Resvcue']
#  ['RESV_304' 'Aorta Resvcue']
#  ['RESV_306' 'Aorta Resvcue']
#  ['RESV_307' 'Aorta Resvcue']
#  ['RESV_308' 'Aorta Resvcue']
#  ['RESV_310' 'Aorta Resvcue']
#  ['RESV_311' 'Aorta Resvcue']
#  ['RESV_312' 'Aorta Resvcue']
#  ['RESV_600' 'Aorta Resvcue']
#  ['16-02-24_201_done' 'Aorta CoA']
#  ['16-03-11_204_done' 'Aorta CoA']
#  ['16-04-01_203_done' 'Aorta CoA']
#  ['16-04-01_209_done' 'Aorta CoA']
#  ['16-04-20_212_done' 'Aorta CoA']
#  ['16-05-11_208_done' 'Aorta CoA']
#  ['16-05-18_215_done' 'Aorta CoA']
#  ['16-05-20_217_done' 'Aorta CoA']
#  ['16-05-27_213_done' 'Aorta CoA']
#  ['16-06-15_202_done' 'Aorta CoA']
#  ['16-06-15_224_done' 'Aorta CoA']
#  ['16-06-29_221_done1' 'Aorta CoA']
#  ['16-07-06_216_done1' 'Aorta CoA']
#  ['16-07-22_226_done1' 'Aorta CoA']
#  ['16-07-22_227_done1' 'Aorta CoA']
#  ['16-07-22_228_done1' 'Aorta CoA']
#  ['16-08-10_233_done1' 'Aorta CoA']
#  ['16-08-10_234_done1' 'Aorta CoA']
#  ['16-08-12_235_done1' 'Aorta CoA']
#  ['16-08-24_239_done1' 'Aorta CoA']
#  ['16-09-07_240_done1' 'Aorta CoA']
#  ['16-09-09_241_done1' 'Aorta CoA']
#  ['16-09-14_242_done1' 'Aorta CoA']
#  ['16-09-16_243_done1' 'Aorta CoA']
#  ['16-09-28_244_done1' 'Aorta CoA']]
