# %% [markdown]
# #### Colab run

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
cd drive/MyDrive/master_thesis/final_code
# Out:
# /content/drive/.shortcut-targets-by-id/16udig9ZMaNcASs5Maj6kv7tg-TL3PnSE/Master Thesis/final_code

# %%
# !pip install kornia
# !pip install torchinfo
# Out:
# Requirement already satisfied: kornia in /usr/local/lib/python3.7/dist-packages (0.5.8)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from kornia) (1.9.0+cu102)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->kornia) (3.7.4.3)
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.7/dist-packages (1.5.3)

# %%
# !nvidia-smi
# Out:
# Tue Aug 24 12:52:12 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# #### Imports

# %%
import warnings
import time

from py_files.args import *

from py_files.functions import *

from py_files.dataset import *

from py_files.cnn_models import *
from py_files.mapping_models import *
from py_files.pigan_model import *

from py_files.load_utils import *
from py_files.data_utils import *
from py_files.plot_utils import *
from py_files.loss_utils import *
from py_files.train_utils import *
from py_files.save_utils import *

# %% [markdown]
# ### 8-net

# %%
# evaluations = [
#                ("reconstruction", None), 
#                ("segmentation_bin", "binary"), 
#                ("segmentation_sdf", "sdf")
#                ]

# for evaluation, seg_type in evaluations: 
#     for i in range(1):
#         ARGS = init_ARGS()
    
#         ARGS.print_models = True 
#         ARGS.save_models = False
#         ARGS.eval_every = 1
        
#         ARGS.pcmra_epochs = 2 
#         ARGS.mask_epochs = 2

#         # Setup changes here
#         setup = "8net"
#         ARGS.mapping_setup = "golden"

#         ARGS.name = f"{evaluation}_{setup}_run_{i}"
#         print(f"Starting training {ARGS.name}.")
#         if "reconstruction" in evaluation: 
#             print(vars(ARGS))
            
#             reconstruction(ARGS) 
        
#         if "segmentation" in evaluation: 
#             ARGS.segmentation = seg_type
#             print(vars(ARGS))
            
#             segmentation(ARGS) 
        
#         torch.cuda.empty_cache()

# %% [markdown]
# ### 4-net

# %%
evaluations = [
            #    ("reconstruction", None), 
               ("segmentation_bin", "binary"), 
               ("segmentation_sdf", "sdf")
               ]

for evaluation, seg_type in evaluations: 
    for i in range(3):
        ARGS = init_ARGS()
    
        # ARGS.print_models = True 
        # ARGS.save_models = False
        # ARGS.eval_every = 1
        
        # ARGS.pcmra_epochs = 2 
        # ARGS.mask_epochs = 2

        # Setup changes here
        setup = "4net"
        ARGS.mapping_setup = "4net"

        ARGS.name = f"{evaluation}_{setup}_run_{i}"
        print(f"Starting training {ARGS.name}.")
        if "reconstruction" in evaluation: 
            print(vars(ARGS))
            
            reconstruction(ARGS) 
        
        if "segmentation" in evaluation: 
            ARGS.segmentation = seg_type
            print(vars(ARGS))
            
            segmentation(ARGS) 
        
        torch.cuda.empty_cache()
# Out:
# WARNING: ARGS class initialized.
# Starting training segmentation_bin_4net_run_0.
# {'device': 'GPU', 'print_models': False, 'save_models': True, 'name': 'segmentation_bin_4net_run_0', 'pretrained': None, 'pretrained_best_dataset': 'train', 'pretrained_best_loss': 'mask', 'pretrained_models': None, 'pretrained_lr_reset': None, 'seed': 34, 'n_coords_sample': 5000, 'norm_min_max': [0, 1], 'rotate': True, 'translate': True, 'crop': True, 'stretch': True, 'flip': False, 'translate_max_pixels': 20, 'stretch_factor': 1.2, 'pcmra_epochs': 5000, 'mask_epochs': 5000, 'batch_size': 24, 'eval_every': 50, 'shuffle': True, 'min_lr': 1e-05, 'patience': 50, 'cnn_setup': 'golden', 'mapping_setup': '4net', 'dim_hidden': 256, 'siren_hidden_layers': 3, 'first_omega_0': 30.0, 'hidden_omega_0': 30.0, 'pcmra_first_omega_0': 30.0, 'pcmra_hidden_omega_0': 30.0, 'segmentation': 'binary', 'cnn_lr': 0.0001, 'mapping_lr': 0.0001, 'pcmra_mapping_lr': 0.0001, 'siren_lr': 0.0001, 'pcmra_siren_lr': 0.0001, 'cnn_wd': 0, 'siren_wd': 0, 'pcmra_siren_wd': 0, 'lambda_sdf': 300.0, 'lambda_inter': 50.0, 'lambda_normal': 10.0, 'lambda_grad': 5.0, 'sdf_split': 0.5}
# saved_runs/pi_gan_2021_08_24_12_52_15_segmentation_bin_4net_run_0
# ----------------------------------
# Using device for training: cuda
# ----------------------------------
# Train subjects: 82
# Train batch: ('6', '102', '28', '115', '9')
# Val subjects: 32
# Val batch: ('10', '121', '11', '129', '131')
# Test subjects: 30
# Test batch: ('133', '134', '15', '142', '138')
# CNN
# MAPPING
# SIREN
# PCMRA_MAPPING
# PCMRA_SIREN
# Epoch 0, train loss 0.62228
# Epoch 0 took 4.32 seconds.
# mask_loss       Train: 0.576420, 	 Eval: 0.571553
# New best train loss, saving model.
# New best eval  loss, saving model.
# dice_loss       Train: 1.000000, 	 Eval: 1.000000
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 1, train loss 0.50201
# Epoch 2, train loss 0.42548
# Epoch 3, train loss 0.39455
# Epoch 4, train loss 0.36548
# Epoch 5, train loss 0.34739
# Epoch 6, train loss 0.32418
# Epoch 7, train loss 0.30997
# Epoch 8, train loss 0.29054
# Epoch 9, train loss 0.28187
# Epoch 10, train loss 0.2737
# Epoch 11, train loss 0.2659
# Epoch 12, train loss 0.25342
# Epoch 13, train loss 0.24842
# Epoch 14, train loss 0.24225
# Epoch 15, train loss 0.23247
# Epoch 16, train loss 0.22826
# Epoch 17, train loss 0.22382
# Epoch 18, train loss 0.22178
# Epoch 19, train loss 0.21868
# Epoch 20, train loss 0.22512
# Epoch 21, train loss 0.21355
# Epoch 22, train loss 0.21888
# Epoch 23, train loss 0.21035
# Epoch 24, train loss 0.21519
# Epoch 25, train loss 0.20944
# Epoch 26, train loss 0.20796
# Epoch 27, train loss 0.2135
# Epoch 28, train loss 0.20696
# Epoch 29, train loss 0.20573
# Epoch 30, train loss 0.2048
# Epoch 31, train loss 0.20127
# Epoch 32, train loss 0.20981
# Epoch 33, train loss 0.20124
# Epoch 34, train loss 0.19832
# Epoch 35, train loss 0.198
# Epoch 36, train loss 0.20122
# Epoch 37, train loss 0.19499
# Epoch 38, train loss 0.19512
# Epoch 39, train loss 0.19577
# Epoch 40, train loss 0.19557
# Epoch 41, train loss 0.19162
# Epoch 42, train loss 0.18834
# Epoch 43, train loss 0.1802
# Epoch 44, train loss 0.18263
# Epoch 45, train loss 0.18749
# Epoch 46, train loss 0.18215
# Epoch 47, train loss 0.17701
# Epoch 48, train loss 0.17687
# Epoch 49, train loss 0.18171
# Epoch 50, train loss 0.17146
# Epoch 50 took 4.17 seconds.
# mask_loss       Train: 0.121536, 	 Eval: 0.119610
# New best train loss, saving model.
# New best eval  loss, saving model.
# dice_loss       Train: 1.000000, 	 Eval: 1.000000
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 51, train loss 0.18603
# Epoch 52, train loss 0.17396
# Epoch 53, train loss 0.16663
# Epoch 54, train loss 0.1651
# Epoch 55, train loss 0.16873
# Epoch 56, train loss 0.16919
# Epoch 57, train loss 0.16969
# Epoch 58, train loss 0.16071
# Epoch 59, train loss 0.16476
# Epoch 60, train loss 0.15646
# Epoch 61, train loss 0.16119
# Epoch 62, train loss 0.16197
# Epoch 63, train loss 0.15605
# Epoch 64, train loss 0.16088
# Epoch 65, train loss 0.15642
# Epoch 66, train loss 0.15896
# Epoch 67, train loss 0.15207
# Epoch 68, train loss 0.15557
# Epoch 69, train loss 0.1478
# Epoch 70, train loss 0.15436
# Epoch 71, train loss 0.15135
# Epoch 72, train loss 0.15739
# Epoch 73, train loss 0.15022
# Epoch 74, train loss 0.14912
# Epoch 75, train loss 0.14465
# Epoch 76, train loss 0.14732
# Epoch 77, train loss 0.15033
# Epoch 78, train loss 0.14534
# Epoch 79, train loss 0.1445
# Epoch 80, train loss 0.1395
# Epoch 81, train loss 0.14783
# Epoch 82, train loss 0.14807
# Epoch 83, train loss 0.14026
# Epoch 84, train loss 0.14489
# Epoch 85, train loss 0.14975
# Epoch 86, train loss 0.1407
# Epoch 87, train loss 0.15134
# Epoch 88, train loss 0.13515
# Epoch 89, train loss 0.13916
# Epoch 90, train loss 0.14813
# Epoch 91, train loss 0.1438
# Epoch 92, train loss 0.13899
# Epoch 93, train loss 0.1357
# Epoch 94, train loss 0.12941
# Epoch 95, train loss 0.14354
# Epoch 96, train loss 0.13237
# Epoch 97, train loss 0.12929
# Epoch 98, train loss 0.13623
# Epoch 99, train loss 0.13468
# Epoch 100, train loss 0.13504
# Epoch 100 took 4.17 seconds.
# mask_loss       Train: 0.073309, 	 Eval: 0.071353
# New best train loss, saving model.
# New best eval  loss, saving model.
# dice_loss       Train: 0.521655, 	 Eval: 0.501435
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 101, train loss 0.12866
# Epoch 102, train loss 0.14363
# Epoch 103, train loss 0.13228
# Epoch 104, train loss 0.13984
# Epoch 105, train loss 0.13636
# Epoch 106, train loss 0.12978
# Epoch 107, train loss 0.12046
# Epoch 108, train loss 0.12278
# Epoch 109, train loss 0.12898
# Epoch 110, train loss 0.12489
# Epoch 111, train loss 0.1276
# Epoch 112, train loss 0.12565
# Epoch 113, train loss 0.12385
# Epoch 114, train loss 0.1201
# Epoch 115, train loss 0.12827
# Epoch 116, train loss 0.11992
# Epoch 117, train loss 0.11609
# Epoch 118, train loss 0.11668
# Epoch 119, train loss 0.11585
# Epoch 120, train loss 0.1174
# Epoch 121, train loss 0.11548
# Epoch 122, train loss 0.11241
# Epoch 123, train loss 0.11758
# Epoch 124, train loss 0.11275
# Epoch 125, train loss 0.11831
# Epoch 126, train loss 0.11094
# Epoch 127, train loss 0.11523
# Epoch 128, train loss 0.12182
# Epoch 129, train loss 0.11366
# Epoch 130, train loss 0.11697
# Epoch 131, train loss 0.11381
# Epoch 132, train loss 0.11137
# Epoch 133, train loss 0.10947
# Epoch 134, train loss 0.10822
# Epoch 135, train loss 0.11164
# Epoch 136, train loss 0.11166
# Epoch 137, train loss 0.10231
# Epoch 138, train loss 0.10888
# Epoch 139, train loss 0.10654
# Epoch 140, train loss 0.10503
# Epoch 141, train loss 0.10569
# Epoch 142, train loss 0.10936
# Epoch 143, train loss 0.09822
# Epoch 144, train loss 0.09802
# Epoch 145, train loss 0.10138
# Epoch 146, train loss 0.0971
# Epoch 147, train loss 0.09989
# Epoch 148, train loss 0.10474
# Epoch 149, train loss 0.10183
# Epoch 150, train loss 0.10288
# Epoch 150 took 4.17 seconds.
# mask_loss       Train: 0.063494, 	 Eval: 0.066688
# New best train loss, saving model.
# New best eval  loss, saving model.
# dice_loss       Train: 0.424227, 	 Eval: 0.447828
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 151, train loss 0.10842
# Epoch 152, train loss 0.1126
# Epoch 153, train loss 0.105
# Epoch 154, train loss 0.10096
# Epoch 155, train loss 0.09904
# Epoch 156, train loss 0.10211
# Epoch 157, train loss 0.09881
# Epoch 158, train loss 0.09938
# Epoch 159, train loss 0.10331
# Epoch 160, train loss 0.10452
# Epoch 161, train loss 0.09821
# Epoch 162, train loss 0.09645
# Epoch 163, train loss 0.09751
# Epoch 164, train loss 0.09488
# Epoch 165, train loss 0.09625
# Epoch 166, train loss 0.09497
# Epoch 167, train loss 0.09604
# Epoch 168, train loss 0.09119
# Epoch 169, train loss 0.08835
# Epoch 170, train loss 0.09328
# Epoch 171, train loss 0.08411
# Epoch 172, train loss 0.09484
# Epoch 173, train loss 0.09556
# Epoch 174, train loss 0.0901
# Epoch 175, train loss 0.09643
# Epoch 176, train loss 0.09222
# Epoch 177, train loss 0.08868
# Epoch 178, train loss 0.08693
# Epoch 179, train loss 0.0945
# Epoch 180, train loss 0.09165
# Epoch 181, train loss 0.09261
# Epoch 182, train loss 0.08322
# Epoch 183, train loss 0.09121
# Epoch 184, train loss 0.08879
# Epoch 185, train loss 0.08641
# Epoch 186, train loss 0.09133
# Epoch 187, train loss 0.09258
# Epoch 188, train loss 0.08847
# Epoch 189, train loss 0.08776
# Epoch 190, train loss 0.0933
# Epoch 191, train loss 0.08606
# Epoch 192, train loss 0.08992
# Epoch 193, train loss 0.09426
# Epoch 194, train loss 0.0935
# Epoch 195, train loss 0.08689
# Epoch 196, train loss 0.0927
# Epoch 197, train loss 0.08737
# Epoch 198, train loss 0.09032
# Epoch 199, train loss 0.08604
# Epoch 200, train loss 0.08952
# Epoch 200 took 4.18 seconds.
# mask_loss       Train: 0.045916, 	 Eval: 0.049771
# New best train loss, saving model.
# New best eval  loss, saving model.
# dice_loss       Train: 0.328148, 	 Eval: 0.364887
# New best train loss, saving model.
# New best eval  loss, saving model.
# WARNING: ARGS class initialized.
# Starting training segmentation_bin_4net_run_1.
# {'device': 'GPU', 'print_models': False, 'save_models': True, 'name': 'segmentation_bin_4net_run_1', 'pretrained': None, 'pretrained_best_dataset': 'train', 'pretrained_best_loss': 'mask', 'pretrained_models': None, 'pretrained_lr_reset': None, 'seed': 34, 'n_coords_sample': 5000, 'norm_min_max': [0, 1], 'rotate': True, 'translate': True, 'crop': True, 'stretch': True, 'flip': False, 'translate_max_pixels': 20, 'stretch_factor': 1.2, 'pcmra_epochs': 5000, 'mask_epochs': 5000, 'batch_size': 24, 'eval_every': 50, 'shuffle': True, 'min_lr': 1e-05, 'patience': 50, 'cnn_setup': 'golden', 'mapping_setup': '4net', 'dim_hidden': 256, 'siren_hidden_layers': 3, 'first_omega_0': 30.0, 'hidden_omega_0': 30.0, 'pcmra_first_omega_0': 30.0, 'pcmra_hidden_omega_0': 30.0, 'segmentation': 'binary', 'cnn_lr': 0.0001, 'mapping_lr': 0.0001, 'pcmra_mapping_lr': 0.0001, 'siren_lr': 0.0001, 'pcmra_siren_lr': 0.0001, 'cnn_wd': 0, 'siren_wd': 0, 'pcmra_siren_wd': 0, 'lambda_sdf': 300.0, 'lambda_inter': 50.0, 'lambda_normal': 10.0, 'lambda_grad': 5.0, 'sdf_split': 0.5}
# saved_runs/pi_gan_2021_08_24_13_08_17_segmentation_bin_4net_run_1
# ----------------------------------
# Using device for training: cuda
# ----------------------------------
# Train subjects: 82
# Train batch: ('68', '7', '43', '48', '65')
# Val subjects: 32
# Val batch: ('10', '121', '11', '129', '131')
# Test subjects: 30
# Test batch: ('133', '134', '15', '142', '138')
# CNN
# MAPPING
# SIREN
# PCMRA_MAPPING
# PCMRA_SIREN
# Epoch 0, train loss 0.67712
# Epoch 0 took 4.27 seconds.
# mask_loss       Train: 0.578190, 	 Eval: 0.576845
# New best train loss, saving model.
# New best eval  loss, saving model.
# dice_loss       Train: 1.000000, 	 Eval: 1.000000
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 1, train loss 0.52091
# Epoch 2, train loss 0.44489
# Epoch 3, train loss 0.41012
# Epoch 4, train loss 0.3843
# Epoch 5, train loss 0.35719
# Epoch 6, train loss 0.33724
# Epoch 7, train loss 0.32087
# Epoch 8, train loss 0.30624
# Epoch 9, train loss 0.28702
# Epoch 10, train loss 0.28022
# Epoch 11, train loss 0.26835
# Epoch 12, train loss 0.2585
# Epoch 13, train loss 0.25566
# Epoch 14, train loss 0.24594
# Epoch 15, train loss 0.23668
# Epoch 16, train loss 0.24002
# Epoch 17, train loss 0.23479
# Epoch 18, train loss 0.22893
# Epoch 19, train loss 0.22079
# Epoch 20, train loss 0.23006
# Epoch 21, train loss 0.22084
# Epoch 22, train loss 0.22215
# Epoch 23, train loss 0.21008
# Epoch 24, train loss 0.22072
# Epoch 25, train loss 0.21653
# Epoch 26, train loss 0.21905
# Epoch 27, train loss 0.21066
# Epoch 28, train loss 0.21053
# Epoch 29, train loss 0.21449
# Epoch 30, train loss 0.20808
# Epoch 31, train loss 0.20721
# Epoch 32, train loss 0.21449
# Epoch 33, train loss 0.20769
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-8f27b12f5710> in <module>()
#      31             print(vars(ARGS))
#      32
# ---> 33             segmentation(ARGS)
#      34
#      35         torch.cuda.empty_cache()
#
# /content/drive/.shortcut-targets-by-id/16udig9ZMaNcASs5Maj6kv7tg-TL3PnSE/Master Thesis/final_code/py_files/train_utils.py in segmentation(ARGS)
#      77             model.train()
#      78
# ---> 79         loss, _ = train_segmentation(train_dl, models, optims, schedulers, blur_layer, ARGS)
#      80
#      81         print(f"Epoch {ep}, train loss {loss.round(5)}")
#
# /content/drive/.shortcut-targets-by-id/16udig9ZMaNcASs5Maj6kv7tg-TL3PnSE/Master Thesis/final_code/py_files/train_utils.py in train_segmentation(dataloader, models, optims, schedulers, blur_layer, ARGS, train_encoder_seg)
#     262         loss.backward()
#     263
# --> 264         losses.append(loss.item())
#     265
#     266         for key in model_keys:
#
# KeyboardInterrupt:

# %% [markdown]
# ### 2net

# %%
evaluations = [
               ("reconstruction", None), 
               ("segmentation_bin", "binary"), 
               ("segmentation_sdf", "sdf")
               ]

for evaluation, seg_type in evaluations: 
    for i in range(1):
        ARGS = init_ARGS()
    
        # ARGS.print_models = True 
        # ARGS.save_models = False
        # ARGS.eval_every = 1
        
        # ARGS.pcmra_epochs = 2 
        # ARGS.mask_epochs = 2

        # Setup changes here
        setup = "2net"
        ARGS.mapping_setup = "2net"

        ARGS.name = f"{evaluation}_{setup}_run_{i}"
        print(f"Starting training {ARGS.name}.")
        
        if "reconstruction" in evaluation: 
            print(vars(ARGS))
            
            reconstruction(ARGS) 
        
        if "segmentation" in evaluation: 
            ARGS.segmentation = seg_type
            print(vars(ARGS))
            
            segmentation(ARGS) 
        
        torch.cuda.empty_cache()

# %% [markdown]
# ### 1net

# %%
evaluations = [
               ("reconstruction", None), 
               ("segmentation_bin", "binary"), 
               ("segmentation_sdf", "sdf")
               ]

for evaluation, seg_type in evaluations: 
    for i in range(1):
        ARGS = init_ARGS()
    
        # ARGS.print_models = True 
        # ARGS.save_models = False
        # ARGS.eval_every = 1
        
        # ARGS.pcmra_epochs = 2 
        # ARGS.mask_epochs = 2

        # Setup changes here
        setup = "1net"
        ARGS.mapping_setup = "1net"

        ARGS.name = f"{evaluation}_{setup}_run_{i}"
        print(f"Starting training {ARGS.name}.")
        
        if "reconstruction" in evaluation: 
            print(vars(ARGS))
            
            reconstruction(ARGS) 
        
        if "segmentation" in evaluation: 
            ARGS.segmentation = seg_type
            print(vars(ARGS))
            
            segmentation(ARGS) 
        
        torch.cuda.empty_cache()
