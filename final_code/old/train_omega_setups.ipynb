# %% [markdown]
# #### Colab run

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
cd drive/MyDrive/master_thesis/final_code
# Out:
# /content/drive/.shortcut-targets-by-id/16udig9ZMaNcASs5Maj6kv7tg-TL3PnSE/Master Thesis/final_code

# %%
# !pip install kornia -qqq
# !pip install torchinfo -qqq
# !pip install wandb -qqq
# Out:
#      |████████████████████████████████| 1.7 MB 8.3 MB/s
#      |████████████████████████████████| 133 kB 88.0 MB/s
#      |████████████████████████████████| 170 kB 90.5 MB/s
#      |████████████████████████████████| 97 kB 8.3 MB/s
#      |████████████████████████████████| 63 kB 2.2 MB/s
#   Building wheel for subprocess32 (setup.py) ... done
#   Building wheel for pathtools (setup.py) ... done

# %%
# !nvidia-smi
# Out:
# Fri Aug 27 07:41:26 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# #### Imports

# %%
import warnings
import time

from py_files.args import *

from py_files.functions import *

from py_files.dataset import *

from py_files.cnn_models import *
from py_files.mapping_models import *
from py_files.pigan_model import *

from py_files.load_utils import *
from py_files.data_utils import *
from py_files.plot_utils import *
from py_files.loss_utils import *
from py_files.train_utils import *
from py_files.save_utils import *

# %% [markdown]
# ### Different omega_0

# %%
training_setups = [
               ("reconstruction", None, 300), 
               ("segmentation", "binary", 300), 
               ("segmentation", "sdf", 300)
               ("reconstruction", None, 10), 
               ("segmentation", "binary", 10), 
               ("segmentation", "sdf", 10)
               ("reconstruction", None, 100), 
               ("segmentation", "binary", 100), 
               ("segmentation", "sdf", 100)
               ]

for i in range(1):

for training_setup, segmentation, omega_0 in training_setups: 

    ARGS = init_ARGS()

    ARGS.first_omega_0 = omega_0
    ARGS.pcmra_first_omega_0 = omega_0
    
    ARGS.training_setup = training_setup
    ARGS.segmentation = segmentation

    print(f"Starting training {ARGS.name}.")
    
    print(vars(ARGS))
        
    complete_training(ARGS)  
            
    torch.cuda.empty_cache()
# Out:
# WARNING: ARGS class initialized.
# Starting training reconstruction_omega_300_run_0.
# {'device': 'GPU', 'print_models': False, 'save_models': True, 'name': 'reconstruction_omega_300_run_0', 'pretrained': None, 'pretrained_best_dataset': 'train', 'pretrained_best_loss': 'mask', 'pretrained_models': None, 'pretrained_lr_reset': None, 'seed': 34, 'n_coords_sample': 5000, 'norm_min_max': [0, 1], 'rotate': True, 'translate': True, 'crop': True, 'stretch': True, 'flip': False, 'translate_max_pixels': 20, 'stretch_factor': 1.2, 'pcmra_epochs': 5000, 'mask_epochs': 5000, 'batch_size': 24, 'eval_every': 50, 'shuffle': True, 'min_lr': 1e-05, 'patience': 50, 'cnn_setup': 'golden', 'mapping_setup': 'golden', 'dim_hidden': 256, 'siren_hidden_layers': 3, 'first_omega_0': 300, 'hidden_omega_0': 30.0, 'pcmra_first_omega_0': 300, 'pcmra_hidden_omega_0': 30.0, 'segmentation': 'binary', 'cnn_lr': 0.0001, 'mapping_lr': 0.0001, 'pcmra_mapping_lr': 0.0001, 'siren_lr': 0.0001, 'pcmra_siren_lr': 0.0001, 'cnn_wd': 0, 'siren_wd': 0, 'pcmra_siren_wd': 0, 'lambda_sdf': 300.0, 'lambda_inter': 50.0, 'lambda_normal': 10.0, 'lambda_grad': 5.0, 'sdf_split': 0.5}
# /usr/local/lib/python3.7/dist-packages/tornado/httputil.py:107: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   class HTTPHeaders(collections.MutableMapping):
# /usr/local/lib/python3.7/dist-packages/jsonschema/compat.py:6: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import MutableMapping, Sequence  # noqa
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: paulltk (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">frosty-feather-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/paulltk/Reconstruction" target="_blank">https://wandb.ai/paulltk/Reconstruction</a><br/>
#                 Run page: <a href="https://wandb.ai/paulltk/Reconstruction/runs/igdfb7wx" target="_blank">https://wandb.ai/paulltk/Reconstruction/runs/igdfb7wx</a><br/>
#                 Run data is saved locally in <code>/content/drive/.shortcut-targets-by-id/16udig9ZMaNcASs5Maj6kv7tg-TL3PnSE/Master Thesis/final_code/wandb/run-20210827_074406-igdfb7wx</code><br/><br/>
# saved_runs/pi_gan_2021_08_27_07_44_14_reconstruction_omega_300_run_0
# ----------------------------------
# Using device for training: cuda
# ----------------------------------
# Train subjects: 82
# Train batch: ('53', '2', '47', '89', '112')
# Val subjects: 32
# Val batch: ('10', '121', '11', '129', '131')
# Test subjects: 30
# Test batch: ('133', '134', '15', '142', '138')
# CNN
# MAPPING
# SIREN
# PCMRA_MAPPING
# PCMRA_SIREN
# Epoch 0, train loss 0.038791
# Epoch 0 took 6.48 seconds.
# pcmra_loss      Train: 0.027900, 	 Eval: 0.028662
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 10, train loss 0.023181
# Epoch 20, train loss 0.021709
# Epoch 30, train loss 0.021151
# Epoch 40, train loss 0.020171
# Epoch 50, train loss 0.014173
# Epoch 50 took 7.22 seconds.
# pcmra_loss      Train: 0.013796, 	 Eval: 0.015132
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 60, train loss 0.012011
# Epoch 70, train loss 0.012475
# Epoch 80, train loss 0.011075
# Epoch 90, train loss 0.012047
# Epoch 100, train loss 0.011186
# Epoch 100 took 7.26 seconds.
# pcmra_loss      Train: 0.010893, 	 Eval: 0.011636
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 110, train loss 0.010797
# Epoch 120, train loss 0.012035
# Epoch 130, train loss 0.011489
# Epoch 140, train loss 0.010806
# Epoch 150, train loss 0.011165
# Epoch 150 took 7.24 seconds.
# pcmra_loss      Train: 0.010402, 	 Eval: 0.011672
# New best train loss, saving model.
# Epoch 160, train loss 0.010827
# Epoch 170, train loss 0.009859
# Epoch 180, train loss 0.009494
# Epoch 190, train loss 0.009485
# Epoch 200, train loss 0.010295
# Epoch 200 took 7.33 seconds.
# pcmra_loss      Train: 0.009874, 	 Eval: 0.010719
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 210, train loss 0.010343
# Epoch 220, train loss 0.009782
# Epoch 230, train loss 0.009375
# Epoch 240, train loss 0.009301
# Epoch 250, train loss 0.009833
# Epoch 250 took 7.31 seconds.
# pcmra_loss      Train: 0.009392, 	 Eval: 0.010623
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 260, train loss 0.009527
# Epoch 270, train loss 0.009687
# Epoch 280, train loss 0.008567
# Epoch 290, train loss 0.00986
# Epoch 300, train loss 0.009242
# Epoch 300 took 7.29 seconds.
# pcmra_loss      Train: 0.008914, 	 Eval: 0.010759
# New best train loss, saving model.
# Epoch 310, train loss 0.008651
# Epoch 320, train loss 0.008594
# Epoch 330, train loss 0.008325
# Epoch 340, train loss 0.009144
# Epoch 350, train loss 0.008276
# Epoch 350 took 7.25 seconds.
# pcmra_loss      Train: 0.008517, 	 Eval: 0.009742
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 360, train loss 0.00882
# Epoch 370, train loss 0.008119
# Epoch 380, train loss 0.007724
# Epoch 390, train loss 0.00805
# Epoch 400, train loss 0.008257
# Epoch 400 took 7.28 seconds.
# pcmra_loss      Train: 0.008214, 	 Eval: 0.009850
# New best train loss, saving model.
# Epoch 410, train loss 0.007982
# Epoch 420, train loss 0.007885
# Epoch 430, train loss 0.007814
# Epoch 440, train loss 0.008768
# Epoch 450, train loss 0.007825
# Epoch 450 took 7.23 seconds.
# pcmra_loss      Train: 0.007872, 	 Eval: 0.009507
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 460, train loss 0.00795
# Epoch 470, train loss 0.007599
# Epoch 480, train loss 0.007139
# Epoch 490, train loss 0.00767
# Epoch 500, train loss 0.007648
# Epoch 500 took 7.27 seconds.
# pcmra_loss      Train: 0.008087, 	 Eval: 0.009970
# Epoch 510, train loss 0.007108
# Epoch 520, train loss 0.007339
# Epoch 530, train loss 0.00727
# Epoch 540, train loss 0.007214
# Epoch 550, train loss 0.006928
# Epoch 550 took 7.27 seconds.
# pcmra_loss      Train: 0.007548, 	 Eval: 0.009458
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 560, train loss 0.006854
# Epoch 570, train loss 0.007407
# Epoch 580, train loss 0.007031
# Epoch 590, train loss 0.006821
# Epoch 600, train loss 0.006424
# Epoch 600 took 7.28 seconds.
# pcmra_loss      Train: 0.006717, 	 Eval: 0.008920
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 610, train loss 0.006667
# Epoch 620, train loss 0.007184
# Epoch 630, train loss 0.006182
# Epoch 640, train loss 0.006552
# Epoch 650, train loss 0.006745
# Epoch 650 took 7.24 seconds.
# pcmra_loss      Train: 0.006956, 	 Eval: 0.008975
# Epoch 660, train loss 0.006375
# Epoch 670, train loss 0.006481
# Epoch 680, train loss 0.006649
# Epoch 690, train loss 0.006695
# Epoch 700, train loss 0.006719
# Epoch 700 took 7.28 seconds.
# pcmra_loss      Train: 0.006899, 	 Eval: 0.008870
# New best eval  loss, saving model.
# Epoch   706: reducing learning rate of group 0 to 5.0000e-05.
# Epoch   706: reducing learning rate of group 0 to 5.0000e-05.
# Epoch   706: reducing learning rate of group 0 to 5.0000e-05.
# Epoch 710, train loss 0.006104
# Epoch 720, train loss 0.00571
# Epoch 730, train loss 0.0061
# Epoch 740, train loss 0.005369
# Epoch 750, train loss 0.005738
# Epoch 750 took 7.26 seconds.
# pcmra_loss      Train: 0.006140, 	 Eval: 0.008682
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 760, train loss 0.00528
# Epoch 770, train loss 0.005306
# Epoch 780, train loss 0.005326
# Epoch 790, train loss 0.005608
# Epoch 800, train loss 0.005483
# Epoch 800 took 7.28 seconds.
# pcmra_loss      Train: 0.005734, 	 Eval: 0.007901
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 810, train loss 0.005392
# Epoch 820, train loss 0.005667
# Epoch 830, train loss 0.005394
# Epoch 840, train loss 0.005533
# Epoch 850, train loss 0.005428
# Epoch 850 took 7.26 seconds.
# pcmra_loss      Train: 0.006028, 	 Eval: 0.008787
# Epoch 860, train loss 0.005682
# Epoch 870, train loss 0.00529
# Epoch 880, train loss 0.004996
# Epoch 890, train loss 0.005181
# Epoch 900, train loss 0.004811
# Epoch 900 took 7.26 seconds.
# pcmra_loss      Train: 0.005793, 	 Eval: 0.008067
# Epoch 910, train loss 0.004914
# Epoch   919: reducing learning rate of group 0 to 2.5000e-05.
# Epoch   919: reducing learning rate of group 0 to 2.5000e-05.
# Epoch   919: reducing learning rate of group 0 to 2.5000e-05.
# Epoch 920, train loss 0.004997
# Epoch 930, train loss 0.004645
# Epoch 940, train loss 0.004797
# Epoch 950, train loss 0.004592
# Epoch 950 took 7.26 seconds.
# pcmra_loss      Train: 0.005383, 	 Eval: 0.008139
# New best train loss, saving model.
# Epoch 960, train loss 0.004537
# Epoch 970, train loss 0.004655
# Epoch 980, train loss 0.004488
# Epoch 990, train loss 0.004687
# Epoch 1000, train loss 0.004692
# Epoch 1000 took 7.26 seconds.
# pcmra_loss      Train: 0.005221, 	 Eval: 0.007893
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 1010, train loss 0.004519
# Epoch 1020, train loss 0.00457
# Epoch 1030, train loss 0.004527
# Epoch 1040, train loss 0.004336
# Epoch 1050, train loss 0.00455
# Epoch 1050 took 7.26 seconds.
# pcmra_loss      Train: 0.005146, 	 Eval: 0.007761
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 1060, train loss 0.004121
# Epoch 1070, train loss 0.004281
# Epoch 1080, train loss 0.004405
# Epoch 1090, train loss 0.004544
# Epoch 1100, train loss 0.004522
# Epoch 1100 took 7.27 seconds.
# pcmra_loss      Train: 0.005228, 	 Eval: 0.007931
# Epoch 1110, train loss 0.004383
# Epoch  1112: reducing learning rate of group 0 to 1.2500e-05.
# Epoch  1112: reducing learning rate of group 0 to 1.2500e-05.
# Epoch  1112: reducing learning rate of group 0 to 1.2500e-05.
# Epoch 1120, train loss 0.00417
# Epoch 1130, train loss 0.004069
# Epoch 1140, train loss 0.004212
# Epoch 1150, train loss 0.004181
# Epoch 1150 took 7.29 seconds.
# pcmra_loss      Train: 0.005016, 	 Eval: 0.007732
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 1160, train loss 0.004094
# Epoch 1170, train loss 0.004285
# Epoch 1180, train loss 0.003946
# Epoch 1190, train loss 0.004042
# Epoch 1200, train loss 0.004205
# Epoch 1200 took 7.27 seconds.
# pcmra_loss      Train: 0.005034, 	 Eval: 0.007890
# Epoch 1210, train loss 0.004176
# Epoch 1220, train loss 0.004066
# Epoch 1230, train loss 0.004737
# Epoch 1240, train loss 0.004656
# Epoch 1250, train loss 0.004226
# Epoch 1250 took 7.29 seconds.
# pcmra_loss      Train: 0.005129, 	 Eval: 0.008037
# Epoch 1260, train loss 0.003922
# Epoch 1270, train loss 0.003979
# Epoch 1280, train loss 0.004098
# Epoch 1290, train loss 0.004312
