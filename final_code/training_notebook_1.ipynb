# %%
from google.colab import drive
drive.mount('/content/drive/')

# !pip install kornia -qqq
# !pip install torchinfo -qqq
# !pip install wandb -qqq
# Out:
# Mounted at /content/drive/
#      |████████████████████████████████| 336 kB 5.1 MB/s
#      |████████████████████████████████| 1.7 MB 5.0 MB/s
#      |████████████████████████████████| 139 kB 50.8 MB/s
#      |████████████████████████████████| 97 kB 7.2 MB/s
#      |████████████████████████████████| 180 kB 48.6 MB/s
#      |████████████████████████████████| 63 kB 1.9 MB/s
#   Building wheel for subprocess32 (setup.py) ... done
#   Building wheel for pathtools (setup.py) ... done

# %%
cd drive/MyDrive/master_thesis/final_code
# Out:
# /content/drive/.shortcut-targets-by-id/16udig9ZMaNcASs5Maj6kv7tg-TL3PnSE/Master Thesis/final_code

# %%
print("test")
# Out:
# test

# %%
# !nvidia-smi
# Out:
# Tue Oct  5 08:55:38 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import warnings
import time

from py_files.args import *

from py_files.functions import *

from py_files.dataset import *

from py_files.cnn_models import *
from py_files.mapping_models import *
from py_files.pigan_model import *

from py_files.load_utils import *
from py_files.data_utils import *
from py_files.plot_utils import *
from py_files.loss_utils import *
from py_files.train_utils import *
from py_files.save_utils import *

# %% [markdown]
# ### Different omega_0

# %%
training_setups = [
               ("segmentation", "sdf", "golden", "golden", "1net", 30, 30), 
               ]


for i in range(5):
    for training_setup, segmentation, cnn_setup, mapping_setup, pcmra_mapping_setup, first_omega_0, pcmra_first_omega_0 in training_setups: 
        ARGS = init_ARGS()

        ARGS.eval_every = 20
        ARGS.mask_epochs = 100 
             
        ARGS.name = "colab_sdf_test"

        ARGS.training_setup = training_setup
        ARGS.segmentation = segmentation

        ARGS.cnn_setup = cnn_setup
        ARGS.mapping_setup = mapping_setup
        ARGS.pcmra_mapping_setup = pcmra_mapping_setup
        
        ARGS.first_omega_0 = first_omega_0
        ARGS.pcmra_first_omega_0 = pcmra_first_omega_0
        
        ARGS.print_models = True
        
        print(f"Starting training {ARGS.name}.")

        print(vars(ARGS))
            
        complete_training(ARGS)  
                
        torch.cuda.empty_cache()
# Out:
# WARNING: ARGS class initialized.
# Starting training colab_sdf_test.
# {'device': 'GPU', 'print_models': True, 'save_models': True, 'name': 'colab_sdf_test', 'training_setup': 'segmentation', 'train_encoder_seg': True, 'pretrained': None, 'pretrained_best_dataset': 'train', 'pretrained_best_loss': 'mask', 'pretrained_models': None, 'pretrained_lr_reset': None, 'seed': 34, 'n_coords_sample': 5000, 'norm_min_max': [0, 1], 'rotate': True, 'translate': True, 'crop': True, 'stretch': True, 'flip': False, 'translate_max_pixels': 20, 'stretch_factor': 1.2, 'pcmra_epochs': 5000, 'mask_epochs': 100, 'batch_size': 24, 'eval_every': 20, 'shuffle': True, 'min_lr': 1e-05, 'patience': 50, 'cnn_setup': 'golden', 'mapping_setup': 'golden', 'dim_hidden': 256, 'siren_hidden_layers': 3, 'first_omega_0': 30, 'hidden_omega_0': 30.0, 'pcmra_first_omega_0': 30, 'pcmra_hidden_omega_0': 30.0, 'segmentation': 'sdf', 'cnn_lr': 0.0001, 'mapping_lr': 0.0001, 'pcmra_mapping_lr': 0.0001, 'siren_lr': 0.0001, 'pcmra_siren_lr': 0.0001, 'cnn_wd': 0, 'siren_wd': 0, 'pcmra_siren_wd': 0, 'lambda_sdf': 300.0, 'lambda_inter': 100.0, 'lambda_normal': 10.0, 'lambda_grad': 5.0, 'sdf_split': 0.5, 'seg_loss_lambda': 0.2, 'pcmra_mapping_setup': '1net'}
# /usr/local/lib/python3.7/dist-packages/tornado/httputil.py:107: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   class HTTPHeaders(collections.MutableMapping):
# /usr/local/lib/python3.7/dist-packages/jsonschema/compat.py:6: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import MutableMapping, Sequence  # noqa
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: paulltk (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/paulltk/segmentation_sdf/runs/1jk8r7bt" target="_blank">colab_sdf_test_golden_golden_30</a></strong> to <a href="https://wandb.ai/paulltk/segmentation_sdf" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# saved_runs/pi_gan_2021_10_05_08_57_16_colab_sdf_test
# ----------------------------------
# Using device for training: cuda
# ----------------------------------
# Train subjects: 82
# Train batch: ('73', '65', '93', '45', '9')
# Val subjects: 32
# Val batch: ('10', '121', '11', '129', '131')
# Test subjects: 30
# Test batch: ('133', '134', '15', '142', '138')
# CNN
# CNN_Golden(
#   (model): Sequential(
#     (0): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(1, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (1): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(8, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((24, 128, 128), eps=1e-05, elementwise_affine=True)
#         (3): MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#     (2): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(8, 16, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (3): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(16, 16, kernel_size=(5, 5, 5), stride=(1, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((24, 32, 32), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (4): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(16, 32, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (5): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(32, 32, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((12, 16, 16), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (6): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(32, 64, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (7): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(64, 64, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((6, 8, 8), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (8): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(64, 128, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (9): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(128, 128, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#   )
# )
# MAPPING
# Mapping_Golden(
#   (gammas): ModuleList(
#     (0): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (1): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (2): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (3): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#   )
#   (betas): ModuleList(
#     (0): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (1): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (2): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (3): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#   )
# )
# SIREN
# Siren(
#   (net): ModuleList(
#     (0): SineLayer(
#       (linear): Linear(in_features=3, out_features=256, bias=True)
#     )
#     (1): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (2): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (3): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (final_linear): Linear(in_features=256, out_features=1, bias=True)
# )
# PCMRA_MAPPING
# Mapping_SingleNetwork(
#   (model): Sequential(
#     (0): Flatten()
#     (1): Linear(in_features=6144, out_features=1024, bias=True)
#     (2): LeakyReLU(negative_slope=0.2)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): ReshapeTensor()
#   )
# )
# PCMRA_SIREN
# Siren(
#   (net): ModuleList(
#     (0): SineLayer(
#       (linear): Linear(in_features=3, out_features=256, bias=True)
#     )
#     (1): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (2): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (3): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (final_linear): Linear(in_features=256, out_features=1, bias=True)
# )
# Epoch 0, train loss 16.81511
# Epoch 0 took 4.67 seconds.
# mask_loss       Train: 0.709025, 	 Eval: 0.709091
# New best train loss, saving model.
# New best eval  loss, saving model.
# dice_loss       Train: 0.943035, 	 Eval: 0.943931
# New best train loss, saving model.
# New best eval  loss, saving model.
# Testing models.
# Loading best pcmra models.
# Loading best mask models.
# Loading params from cnn
# Loading params from mapping
# Loading params from siren
# [3.16960e-02 1.46680e-02 7.09038e-01 3.22000e-04 9.42920e-01 1.56640e-02]
# <br/>Waiting for W&B process to finish, PID 378... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch_sampling_bce_loss</td><td>▁</td></tr><tr><td>epochs</td><td>▁</td></tr><tr><td>eval_bce_loss</td><td>▁</td></tr><tr><td>eval_dice_loss</td><td>▁</td></tr><tr><td>test_bce_loss</td><td>▁</td></tr><tr><td>test_dice_loss</td><td>▁</td></tr><tr><td>test_mse_loss</td><td>▁</td></tr><tr><td>train_bce_loss</td><td>▁</td></tr><tr><td>train_dice_loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch_sampling_bce_loss</td><td>16.81511</td></tr><tr><td>epochs</td><td>0</td></tr><tr><td>eval_bce_loss</td><td>0.70909</td></tr><tr><td>eval_dice_loss</td><td>0.94393</td></tr><tr><td>test_bce_loss</td><td>0.70904</td></tr><tr><td>test_dice_loss</td><td>0.94292</td></tr><tr><td>test_mse_loss</td><td>0.0317</td></tr><tr><td>train_bce_loss</td><td>0.70903</td></tr><tr><td>train_dice_loss</td><td>0.94303</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">colab_sdf_test_golden_golden_30</strong>: <a href="https://wandb.ai/paulltk/segmentation_sdf/runs/1jk8r7bt" target="_blank">https://wandb.ai/paulltk/segmentation_sdf/runs/1jk8r7bt</a><br/>
# Find logs at: <code>./wandb/run-20211005_085708-1jk8r7bt/logs</code><br/>
#                     Syncing run <strong><a href="https://wandb.ai/paulltk/segmentation_sdf/runs/1d1wnaq9" target="_blank">_colab_sdf_test_golden_golden_30</a></strong> to <a href="https://wandb.ai/paulltk/segmentation_sdf" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# saved_runs/pi_gan_2021_10_05_09_00_34__colab_sdf_test
# ----------------------------------
# Using device for training: cuda
# ----------------------------------
# Train subjects: 82
# Train batch: ('74', '73', '7', '120', '5')
# Val subjects: 32
# Val batch: ('10', '121', '11', '129', '131')
# Test subjects: 30
# Test batch: ('133', '134', '15', '142', '138')
# CNN
# CNN_Golden(
#   (model): Sequential(
#     (0): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(1, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (1): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(8, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((24, 128, 128), eps=1e-05, elementwise_affine=True)
#         (3): MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#     (2): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(8, 16, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (3): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(16, 16, kernel_size=(5, 5, 5), stride=(1, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((24, 32, 32), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (4): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(16, 32, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (5): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(32, 32, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((12, 16, 16), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (6): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(32, 64, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (7): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(64, 64, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((6, 8, 8), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (8): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(64, 128, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (9): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(128, 128, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#   )
# )
# MAPPING
# Mapping_Golden(
#   (gammas): ModuleList(
#     (0): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (1): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (2): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (3): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#   )
#   (betas): ModuleList(
#     (0): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (1): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (2): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (3): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#   )
# )
# SIREN
# Siren(
#   (net): ModuleList(
#     (0): SineLayer(
#       (linear): Linear(in_features=3, out_features=256, bias=True)
#     )
#     (1): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (2): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (3): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (final_linear): Linear(in_features=256, out_features=1, bias=True)
# )
# PCMRA_MAPPING
# Mapping_SingleNetwork(
#   (model): Sequential(
#     (0): Flatten()
#     (1): Linear(in_features=6144, out_features=1024, bias=True)
#     (2): LeakyReLU(negative_slope=0.2)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): ReshapeTensor()
#   )
# )
# PCMRA_SIREN
# Siren(
#   (net): ModuleList(
#     (0): SineLayer(
#       (linear): Linear(in_features=3, out_features=256, bias=True)
#     )
#     (1): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (2): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (3): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (final_linear): Linear(in_features=256, out_features=1, bias=True)
# )
# Epoch 0, train loss 17.239128
# Epoch 0 took 4.61 seconds.
# mask_loss       Train: 0.671717, 	 Eval: 0.671680
# New best train loss, saving model.
# New best eval  loss, saving model.
# dice_loss       Train: 1.000000, 	 Eval: 1.000000
# New best train loss, saving model.
# New best eval  loss, saving model.
# Epoch 10, train loss 15.206275
# Epoch 20, train loss 15.293431
# Epoch 20 took 4.56 seconds.
# mask_loss       Train: 0.678347, 	 Eval: 0.678310
# dice_loss       Train: 1.000000, 	 Eval: 1.000000
# Epoch 30, train loss 14.930197
# Epoch 40, train loss 14.883157
# Epoch 40 took 4.55 seconds.
# mask_loss       Train: 0.675926, 	 Eval: 0.676236
# dice_loss       Train: 1.000000, 	 Eval: 1.000000
# Epoch 50, train loss 15.127277
# Epoch 60, train loss 14.784397
# Epoch 60 took 4.55 seconds.
# mask_loss       Train: 0.676935, 	 Eval: 0.677089
# dice_loss       Train: 1.000000, 	 Eval: 1.000000
# Epoch 70, train loss 14.948414
# Epoch 80, train loss 14.970968
# Epoch 80 took 4.56 seconds.
# mask_loss       Train: 0.677424, 	 Eval: 0.677430
# dice_loss       Train: 1.000000, 	 Eval: 1.000000
# Epoch 90, train loss 15.064553
# Testing models.
# Loading best pcmra models.
# Loading best mask models.
# Loading params from cnn
# Loading params from mapping
# Loading params from siren
# [5.51090e-02 2.22730e-02 6.71728e-01 3.76000e-04 1.00000e+00 0.00000e+00]
# <br/>Waiting for W&B process to finish, PID 478... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch_sampling_bce_loss</td><td>█▄▃▃▂▂▂▁▃▃▂▂▂▂▂▂▂▃▃▂▂▂▂▂▁▅▃▂▁▁▂▂▂▁▁▄▂▂▂▁</td></tr><tr><td>epochs</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>eval_bce_loss</td><td>▁█▆▇▇</td></tr><tr><td>eval_dice_loss</td><td>▁▁▁▁▁</td></tr><tr><td>test_bce_loss</td><td>▁</td></tr><tr><td>test_dice_loss</td><td>▁</td></tr><tr><td>test_mse_loss</td><td>▁</td></tr><tr><td>train_bce_loss</td><td>▁█▅▇▇</td></tr><tr><td>train_dice_loss</td><td>▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch_sampling_bce_loss</td><td>14.80129</td></tr><tr><td>epochs</td><td>99</td></tr><tr><td>eval_bce_loss</td><td>0.67743</td></tr><tr><td>eval_dice_loss</td><td>1.0</td></tr><tr><td>test_bce_loss</td><td>0.67173</td></tr><tr><td>test_dice_loss</td><td>1.0</td></tr><tr><td>test_mse_loss</td><td>0.05511</td></tr><tr><td>train_bce_loss</td><td>0.67742</td></tr><tr><td>train_dice_loss</td><td>1.0</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">_colab_sdf_test_golden_golden_30</strong>: <a href="https://wandb.ai/paulltk/segmentation_sdf/runs/1d1wnaq9" target="_blank">https://wandb.ai/paulltk/segmentation_sdf/runs/1d1wnaq9</a><br/>
# Find logs at: <code>./wandb/run-20211005_090029-1d1wnaq9/logs</code><br/>
# WARNING: ARGS class initialized.
# Starting training colab_sdf_test.
# {'device': 'GPU', 'print_models': True, 'save_models': True, 'name': 'colab_sdf_test', 'training_setup': 'segmentation', 'train_encoder_seg': True, 'pretrained': None, 'pretrained_best_dataset': 'train', 'pretrained_best_loss': 'mask', 'pretrained_models': None, 'pretrained_lr_reset': None, 'seed': 34, 'n_coords_sample': 5000, 'norm_min_max': [0, 1], 'rotate': True, 'translate': True, 'crop': True, 'stretch': True, 'flip': False, 'translate_max_pixels': 20, 'stretch_factor': 1.2, 'pcmra_epochs': 5000, 'mask_epochs': 100, 'batch_size': 24, 'eval_every': 20, 'shuffle': True, 'min_lr': 1e-05, 'patience': 50, 'cnn_setup': 'golden', 'mapping_setup': 'golden', 'dim_hidden': 256, 'siren_hidden_layers': 3, 'first_omega_0': 30, 'hidden_omega_0': 30.0, 'pcmra_first_omega_0': 30, 'pcmra_hidden_omega_0': 30.0, 'segmentation': 'sdf', 'cnn_lr': 0.0001, 'mapping_lr': 0.0001, 'pcmra_mapping_lr': 0.0001, 'siren_lr': 0.0001, 'pcmra_siren_lr': 0.0001, 'cnn_wd': 0, 'siren_wd': 0, 'pcmra_siren_wd': 0, 'lambda_sdf': 300.0, 'lambda_inter': 100.0, 'lambda_normal': 10.0, 'lambda_grad': 5.0, 'sdf_split': 0.5, 'seg_loss_lambda': 0.2, 'pcmra_mapping_setup': '1net'}
#                     Syncing run <strong><a href="https://wandb.ai/paulltk/segmentation_sdf/runs/2elrxu0a" target="_blank">colab_sdf_test_golden_golden_30</a></strong> to <a href="https://wandb.ai/paulltk/segmentation_sdf" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# saved_runs/pi_gan_2021_10_05_09_09_50_colab_sdf_test
# ----------------------------------
# Using device for training: cuda
# ----------------------------------
# Train subjects: 82
# Train batch: ('48', '112', '95', '25', '73')
# Val subjects: 32
# Val batch: ('10', '121', '11', '129', '131')
# Test subjects: 30
# Test batch: ('133', '134', '15', '142', '138')
# CNN
# CNN_Golden(
#   (model): Sequential(
#     (0): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(1, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (1): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(8, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((24, 128, 128), eps=1e-05, elementwise_affine=True)
#         (3): MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#     (2): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(8, 16, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (3): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(16, 16, kernel_size=(5, 5, 5), stride=(1, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((24, 32, 32), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (4): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(16, 32, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (5): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(32, 32, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((12, 16, 16), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (6): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(32, 64, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (7): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(64, 64, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((6, 8, 8), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (8): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(64, 128, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (9): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(128, 128, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#   )
# )
# MAPPING
# Mapping_Golden(
#   (gammas): ModuleList(
#     (0): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (1): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (2): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (3): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#   )
#   (betas): ModuleList(
#     (0): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (1): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (2): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (3): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#   )
# )
# SIREN
# Siren(
#   (net): ModuleList(
#     (0): SineLayer(
#       (linear): Linear(in_features=3, out_features=256, bias=True)
#     )
#     (1): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (2): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (3): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (final_linear): Linear(in_features=256, out_features=1, bias=True)
# )
# PCMRA_MAPPING
# Mapping_SingleNetwork(
#   (model): Sequential(
#     (0): Flatten()
#     (1): Linear(in_features=6144, out_features=1024, bias=True)
#     (2): LeakyReLU(negative_slope=0.2)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): ReshapeTensor()
#   )
# )
# PCMRA_SIREN
# Siren(
#   (net): ModuleList(
#     (0): SineLayer(
#       (linear): Linear(in_features=3, out_features=256, bias=True)
#     )
#     (1): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (2): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (3): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (final_linear): Linear(in_features=256, out_features=1, bias=True)
# )
# Epoch 0, train loss 17.05669
# Epoch 0 took 4.54 seconds.
# mask_loss       Train: 0.713075, 	 Eval: 0.713109
# New best train loss, saving model.
# New best eval  loss, saving model.
# dice_loss       Train: 0.943035, 	 Eval: 0.943931
# New best train loss, saving model.
# New best eval  loss, saving model.
# Testing models.
# Loading best pcmra models.
# Loading best mask models.
# Loading params from cnn
# Loading params from mapping
# Loading params from siren
# [2.87640e-02 1.32860e-02 7.13155e-01 4.13000e-04 9.42920e-01 1.56640e-02]
# <br/>Waiting for W&B process to finish, PID 648... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch_sampling_bce_loss</td><td>▁</td></tr><tr><td>epochs</td><td>▁</td></tr><tr><td>eval_bce_loss</td><td>▁</td></tr><tr><td>eval_dice_loss</td><td>▁</td></tr><tr><td>test_bce_loss</td><td>▁</td></tr><tr><td>test_dice_loss</td><td>▁</td></tr><tr><td>test_mse_loss</td><td>▁</td></tr><tr><td>train_bce_loss</td><td>▁</td></tr><tr><td>train_dice_loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch_sampling_bce_loss</td><td>17.05669</td></tr><tr><td>epochs</td><td>0</td></tr><tr><td>eval_bce_loss</td><td>0.71311</td></tr><tr><td>eval_dice_loss</td><td>0.94393</td></tr><tr><td>test_bce_loss</td><td>0.71315</td></tr><tr><td>test_dice_loss</td><td>0.94292</td></tr><tr><td>test_mse_loss</td><td>0.02876</td></tr><tr><td>train_bce_loss</td><td>0.71308</td></tr><tr><td>train_dice_loss</td><td>0.94303</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">colab_sdf_test_golden_golden_30</strong>: <a href="https://wandb.ai/paulltk/segmentation_sdf/runs/2elrxu0a" target="_blank">https://wandb.ai/paulltk/segmentation_sdf/runs/2elrxu0a</a><br/>
# Find logs at: <code>./wandb/run-20211005_090947-2elrxu0a/logs</code><br/>
#                     Syncing run <strong><a href="https://wandb.ai/paulltk/segmentation_sdf/runs/1ujayz8q" target="_blank">_colab_sdf_test_golden_golden_30</a></strong> to <a href="https://wandb.ai/paulltk/segmentation_sdf" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# saved_runs/pi_gan_2021_10_05_09_11_04__colab_sdf_test
# ----------------------------------
# Using device for training: cuda
# ----------------------------------
# Train subjects: 82
# Train batch: ('6', '117', '46', '90', '76')
# Val subjects: 32
# Val batch: ('10', '121', '11', '129', '131')
# Test subjects: 30
# Test batch: ('133', '134', '15', '142', '138')
# CNN
# CNN_Golden(
#   (model): Sequential(
#     (0): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(1, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (1): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(8, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((24, 128, 128), eps=1e-05, elementwise_affine=True)
#         (3): MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#     (2): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(8, 16, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (3): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(16, 16, kernel_size=(5, 5, 5), stride=(1, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((24, 32, 32), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (4): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(16, 32, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (5): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(32, 32, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((12, 16, 16), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (6): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(32, 64, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (7): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(64, 64, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((6, 8, 8), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (8): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(64, 128, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (9): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(128, 128, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#   )
# )
# MAPPING
# Mapping_Golden(
#   (gammas): ModuleList(
#     (0): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (1): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (2): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (3): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#   )
#   (betas): ModuleList(
#     (0): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (1): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (2): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (3): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#   )
# )
# SIREN
# Siren(
#   (net): ModuleList(
#     (0): SineLayer(
#       (linear): Linear(in_features=3, out_features=256, bias=True)
#     )
#     (1): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (2): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (3): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (final_linear): Linear(in_features=256, out_features=1, bias=True)
# )
# PCMRA_MAPPING
# Mapping_SingleNetwork(
#   (model): Sequential(
#     (0): Flatten()
#     (1): Linear(in_features=6144, out_features=1024, bias=True)
#     (2): LeakyReLU(negative_slope=0.2)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): ReshapeTensor()
#   )
# )
# PCMRA_SIREN
# Siren(
#   (net): ModuleList(
#     (0): SineLayer(
#       (linear): Linear(in_features=3, out_features=256, bias=True)
#     )
#     (1): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (2): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (3): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (final_linear): Linear(in_features=256, out_features=1, bias=True)
# )
# Epoch 0, train loss 18.542724
# Epoch 0 took 4.57 seconds.
# mask_loss       Train: 0.708423, 	 Eval: 0.708427
# New best train loss, saving model.
# New best eval  loss, saving model.
# dice_loss       Train: 0.943035, 	 Eval: 0.943931
# New best train loss, saving model.
# New best eval  loss, saving model.
# Testing models.
# Loading best pcmra models.
# Loading best mask models.
# Loading params from cnn
# Loading params from mapping
# Loading params from siren
# [3.07790e-02 1.42610e-02 7.08413e-01 3.11000e-04 9.42920e-01 1.56640e-02]
# <br/>Waiting for W&B process to finish, PID 704... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch_sampling_bce_loss</td><td>▁</td></tr><tr><td>epochs</td><td>▁</td></tr><tr><td>eval_bce_loss</td><td>▁</td></tr><tr><td>eval_dice_loss</td><td>▁</td></tr><tr><td>test_bce_loss</td><td>▁</td></tr><tr><td>test_dice_loss</td><td>▁</td></tr><tr><td>test_mse_loss</td><td>▁</td></tr><tr><td>train_bce_loss</td><td>▁</td></tr><tr><td>train_dice_loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch_sampling_bce_loss</td><td>18.54272</td></tr><tr><td>epochs</td><td>0</td></tr><tr><td>eval_bce_loss</td><td>0.70843</td></tr><tr><td>eval_dice_loss</td><td>0.94393</td></tr><tr><td>test_bce_loss</td><td>0.70841</td></tr><tr><td>test_dice_loss</td><td>0.94292</td></tr><tr><td>test_mse_loss</td><td>0.03078</td></tr><tr><td>train_bce_loss</td><td>0.70842</td></tr><tr><td>train_dice_loss</td><td>0.94303</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">_colab_sdf_test_golden_golden_30</strong>: <a href="https://wandb.ai/paulltk/segmentation_sdf/runs/1ujayz8q" target="_blank">https://wandb.ai/paulltk/segmentation_sdf/runs/1ujayz8q</a><br/>
# Find logs at: <code>./wandb/run-20211005_091058-1ujayz8q/logs</code><br/>
#                     Syncing run <strong><a href="https://wandb.ai/paulltk/segmentation_sdf/runs/2m77s37j" target="_blank">__colab_sdf_test_golden_golden_30</a></strong> to <a href="https://wandb.ai/paulltk/segmentation_sdf" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# saved_runs/pi_gan_2021_10_05_09_12_14___colab_sdf_test
# ----------------------------------
# Using device for training: cuda
# ----------------------------------
# Train subjects: 82
# Train batch: ('7', '117', '69', '66', '112')
# Val subjects: 32
# Val batch: ('10', '121', '11', '129', '131')
# Test subjects: 30
# Test batch: ('133', '134', '15', '142', '138')
# CNN
# CNN_Golden(
#   (model): Sequential(
#     (0): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(1, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (1): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(8, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((24, 128, 128), eps=1e-05, elementwise_affine=True)
#         (3): MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#     (2): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(8, 16, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (3): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(16, 16, kernel_size=(5, 5, 5), stride=(1, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((24, 32, 32), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (4): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(16, 32, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (5): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(32, 32, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((12, 16, 16), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (6): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(32, 64, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (7): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(64, 64, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#         (2): LayerNorm((6, 8, 8), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (8): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(64, 128, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#     (9): ConvLayer(
#       (model): Sequential(
#         (0): Conv3d(128, 128, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(2, 2, 2))
#         (1): ReLU()
#       )
#     )
#   )
# )
# MAPPING
# Mapping_Golden(
#   (gammas): ModuleList(
#     (0): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (1): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (2): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (3): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#   )
#   (betas): ModuleList(
#     (0): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (1): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (2): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (3): Sequential(
#       (0): Flatten()
#       (1): Linear(in_features=6144, out_features=1024, bias=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.2)
#       (5): Linear(in_features=512, out_features=256, bias=True)
#     )
#   )
# )
# SIREN
# Siren(
#   (net): ModuleList(
#     (0): SineLayer(
#       (linear): Linear(in_features=3, out_features=256, bias=True)
#     )
#     (1): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (2): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (3): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (final_linear): Linear(in_features=256, out_features=1, bias=True)
# )
# PCMRA_MAPPING
# Mapping_SingleNetwork(
#   (model): Sequential(
#     (0): Flatten()
#     (1): Linear(in_features=6144, out_features=1024, bias=True)
#     (2): LeakyReLU(negative_slope=0.2)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): ReshapeTensor()
#   )
# )
# PCMRA_SIREN
# Siren(
#   (net): ModuleList(
#     (0): SineLayer(
#       (linear): Linear(in_features=3, out_features=256, bias=True)
#     )
#     (1): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (2): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (3): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (final_linear): Linear(in_features=256, out_features=1, bias=True)
# )
# Epoch 0, train loss 17.688187
# Epoch 0 took 4.56 seconds.
# mask_loss       Train: 0.678738, 	 Eval: 0.678798
# New best train loss, saving model.
# New best eval  loss, saving model.
# dice_loss       Train: 1.000000, 	 Eval: 1.000000
# New best train loss, saving model.
# New best eval  loss, saving model.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-4bf2c3f4fa9c> in <module>()
#      29         print(vars(ARGS))
#      30
# ---> 31         complete_training(ARGS)
#      32
#      33         torch.cuda.empty_cache()
#
# /content/drive/.shortcut-targets-by-id/16udig9ZMaNcASs5Maj6kv7tg-TL3PnSE/Master Thesis/final_code/py_files/train_utils.py in complete_training(ARGS)
#      20         reconstruction(ARGS)
#      21     elif ARGS.training_setup == "segmentation":
# ---> 22         segmentation(ARGS)
#      23     elif ARGS.training_setup == "combined":
#      24         combined(ARGS)
#
# /content/drive/.shortcut-targets-by-id/16udig9ZMaNcASs5Maj6kv7tg-TL3PnSE/Master Thesis/final_code/py_files/train_utils.py in segmentation(ARGS)
#     125                 model.train()
#     126
# --> 127             loss, _ = train_segmentation(train_dl, models, optims, schedulers, blur_layer, ARGS)
#     128
#     129             wandb.log({"epoch_sampling_bce_loss": loss, "epochs": ep}, step=ep)
#
# /content/drive/.shortcut-targets-by-id/16udig9ZMaNcASs5Maj6kv7tg-TL3PnSE/Master Thesis/final_code/py_files/train_utils.py in train_segmentation(dataloader, models, optims, schedulers, blur_layer, ARGS)
#     440         loss.backward()
#     441
# --> 442         losses.append(loss.item())
#     443
#     444         for key in model_keys:
#
# KeyboardInterrupt:
